# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Input, Dense, SimpleRNN, Dropout
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam, Adamax, Ftrl

# %%
# 2. Đọc file csv và gắng index với giá Close
df = pd.read_excel('bnb_processed_data.xlsx')
df1=df.reset_index()['Close']

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# 4. Chia train test
train_size = int(0.7 * len(df1))
test_size = len(df1) - train_size

train_data = df1[:train_size]
test_data = df1[train_size:]
len(df1)
# Out:
# 1919

# %%
test_size,train_size
# Out:
# (576, 1343)

# %%
import numpy as np

# Initiation value of lag
lag = 100

# Sliding windows function
def create_sliding_windows(data, lag):
    x = []
    y = []
    for i in range(len(data) - lag):
        x.append(data[i:i+lag])
        y.append(data[i+lag])  # Append the value at index i+lag as the label y
    return np.array(x), np.array(y)

# # Example usage with training and test data
# train_data = np.array([10, 20, 30, 40, 50, 60, 70, 80, 90])  # Example training data
# test_data = np.array([100, 110, 120, 130, 140])  # Example test data
combined_data = np.concatenate((train_data[-lag:], test_data))

# Create sliding windows for training data
x_train, y_train = create_sliding_windows(train_data, lag)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# Create sliding windows for test data
x_test, y_test = create_sliding_windows(combined_data, lag)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# Print the shapes to verify
print("x_train shape:", x_train.shape)
print("y_train shape:", y_train.shape)
print("x_test shape:", x_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# x_train shape: (1243, 100, 1)
# y_train shape: (1243, 1)
# x_test shape: (576, 100, 1)
# y_test shape: (576, 1)

# %%
# 8. Define LSTM Model

model = Sequential()
model.add(SimpleRNN(50, return_sequences=True, input_shape=(lag, 1)))
model.add(Dropout(0.2))
model.add(SimpleRNN(50, return_sequences=True))
model.add(Dropout(0.2))
model.add(SimpleRNN(50))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer=Ftrl(learning_rate=0.001, l1_regularization_strength=0.0, l2_regularization_strength=0.0))

model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_21 (SimpleRNN)   (None, 100, 50)           2600
#
#  dropout_21 (Dropout)        (None, 100, 50)           0
#
#  simple_rnn_22 (SimpleRNN)   (None, 100, 50)           5050
#
#  dropout_22 (Dropout)        (None, 100, 50)           0
#
#  simple_rnn_23 (SimpleRNN)   (None, 50)                5050
#
#  dropout_23 (Dropout)        (None, 50)                0
#
#  dense_7 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 12751 (49.81 KB)
# Trainable params: 12751 (49.81 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
len(x_train), len(y_train),len(x_test), len(y_test)
# Out:
# (1243, 1243, 576, 576)

# %%
# # 9. Fit mô hình với dữ liệu train
model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 11s 324ms/step - loss: 0.1911 - val_loss: 0.2415
# Epoch 2/100
# 20/20 [==============================] - 4s 221ms/step - loss: 0.1629 - val_loss: 0.2357
# Epoch 3/100
# 20/20 [==============================] - 6s 291ms/step - loss: 0.1597 - val_loss: 0.2311
# Epoch 4/100
# 20/20 [==============================] - 5s 219ms/step - loss: 0.1571 - val_loss: 0.2271
# Epoch 5/100
# 20/20 [==============================] - 4s 220ms/step - loss: 0.1548 - val_loss: 0.2235
# Epoch 6/100
# 20/20 [==============================] - 6s 310ms/step - loss: 0.1529 - val_loss: 0.2203
# Epoch 7/100
# 20/20 [==============================] - 4s 222ms/step - loss: 0.1511 - val_loss: 0.2173
# Epoch 8/100
# 20/20 [==============================] - 4s 223ms/step - loss: 0.1493 - val_loss: 0.2145
# Epoch 9/100
# 20/20 [==============================] - 6s 294ms/step - loss: 0.1477 - val_loss: 0.2119
# Epoch 10/100
# 20/20 [==============================] - 5s 229ms/step - loss: 0.1462 - val_loss: 0.2094
# Epoch 11/100
# 20/20 [==============================] - 8s 402ms/step - loss: 0.1448 - val_loss: 0.2069
# Epoch 12/100
# 20/20 [==============================] - 4s 218ms/step - loss: 0.1435 - val_loss: 0.2046
# Epoch 13/100
# 20/20 [==============================] - 5s 246ms/step - loss: 0.1422 - val_loss: 0.2024
# Epoch 14/100
# 20/20 [==============================] - 6s 270ms/step - loss: 0.1409 - val_loss: 0.2002
# Epoch 15/100
# 20/20 [==============================] - 4s 223ms/step - loss: 0.1397 - val_loss: 0.1982
# Epoch 16/100
# 20/20 [==============================] - 6s 304ms/step - loss: 0.1386 - val_loss: 0.1961
# Epoch 17/100
# 20/20 [==============================] - 4s 221ms/step - loss: 0.1374 - val_loss: 0.1941
# Epoch 18/100
# 20/20 [==============================] - 4s 221ms/step - loss: 0.1362 - val_loss: 0.1922
# Epoch 19/100
# 20/20 [==============================] - 6s 312ms/step - loss: 0.1352 - val_loss: 0.1903
# Epoch 20/100
# 20/20 [==============================] - 4s 222ms/step - loss: 0.1343 - val_loss: 0.1885
# Epoch 21/100
# 20/20 [==============================] - 6s 303ms/step - loss: 0.1333 - val_loss: 0.1867
# Epoch 22/100
# 20/20 [==============================] - 5s 233ms/step - loss: 0.1324 - val_loss: 0.1849
# Epoch 23/100
# 20/20 [==============================] - 4s 219ms/step - loss: 0.1312 - val_loss: 0.1831
# Epoch 24/100
# 20/20 [==============================] - 6s 306ms/step - loss: 0.1303 - val_loss: 0.1814
# Epoch 25/100
# 20/20 [==============================] - 4s 223ms/step - loss: 0.1292 - val_loss: 0.1797
# Epoch 26/100
# 20/20 [==============================] - 5s 253ms/step - loss: 0.1284 - val_loss: 0.1780
# Epoch 27/100
# 20/20 [==============================] - 6s 279ms/step - loss: 0.1277 - val_loss: 0.1763
# Epoch 28/100
# 20/20 [==============================] - 4s 220ms/step - loss: 0.1267 - val_loss: 0.1747
# Epoch 29/100
# 20/20 [==============================] - 6s 304ms/step - loss: 0.1259 - val_loss: 0.1730
# Epoch 30/100
# 20/20 [==============================] - 4s 220ms/step - loss: 0.1248 - val_loss: 0.1714
# Epoch 31/100
# 20/20 [==============================] - 4s 218ms/step - loss: 0.1240 - val_loss: 0.1698
# Epoch 32/100
# 20/20 [==============================] - 6s 308ms/step - loss: 0.1233 - val_loss: 0.1682
# Epoch 33/100
# 20/20 [==============================] - 4s 221ms/step - loss: 0.1226 - val_loss: 0.1666
# Epoch 34/100
# 20/20 [==============================] - 6s 303ms/step - loss: 0.1214 - val_loss: 0.1650
# Epoch 35/100
# 20/20 [==============================] - 4s 219ms/step - loss: 0.1210 - val_loss: 0.1635
# Epoch 36/100
# 20/20 [==============================] - 4s 223ms/step - loss: 0.1201 - val_loss: 0.1620
# Epoch 37/100
# 20/20 [==============================] - 6s 308ms/step - loss: 0.1190 - val_loss: 0.1605
# Epoch 38/100
# 20/20 [==============================] - 4s 221ms/step - loss: 0.1187 - val_loss: 0.1589
# Epoch 39/100
# 20/20 [==============================] - 5s 256ms/step - loss: 0.1176 - val_loss: 0.1574
# Epoch 40/100
# 20/20 [==============================] - 6s 273ms/step - loss: 0.1170 - val_loss: 0.1559
# Epoch 41/100
# 20/20 [==============================] - 4s 223ms/step - loss: 0.1162 - val_loss: 0.1544
# Epoch 42/100
# 20/20 [==============================] - 6s 311ms/step - loss: 0.1158 - val_loss: 0.1530
# Epoch 43/100
# 20/20 [==============================] - 5s 227ms/step - loss: 0.1151 - val_loss: 0.1515
# Epoch 44/100
# 20/20 [==============================] - 4s 224ms/step - loss: 0.1139 - val_loss: 0.1501
# Epoch 45/100
# 20/20 [==============================] - 6s 300ms/step - loss: 0.1133 - val_loss: 0.1486
# Epoch 46/100
# 20/20 [==============================] - 5s 231ms/step - loss: 0.1125 - val_loss: 0.1472
# Epoch 47/100
# 20/20 [==============================] - 6s 317ms/step - loss: 0.1119 - val_loss: 0.1458
# Epoch 48/100
# 20/20 [==============================] - 5s 234ms/step - loss: 0.1116 - val_loss: 0.1443
# Epoch 49/100
# 20/20 [==============================] - 5s 234ms/step - loss: 0.1104 - val_loss: 0.1430
# Epoch 50/100
# 20/20 [==============================] - 6s 286ms/step - loss: 0.1102 - val_loss: 0.1416
# Epoch 51/100
# 20/20 [==============================] - 5s 233ms/step - loss: 0.1093 - val_loss: 0.1402
# Epoch 52/100
# 20/20 [==============================] - 6s 316ms/step - loss: 0.1090 - val_loss: 0.1388
# Epoch 53/100
# 20/20 [==============================] - 4s 224ms/step - loss: 0.1084 - val_loss: 0.1375
# Epoch 54/100
# 20/20 [==============================] - 4s 224ms/step - loss: 0.1075 - val_loss: 0.1361
# Epoch 55/100
# 20/20 [==============================] - 6s 313ms/step - loss: 0.1070 - val_loss: 0.1348
# Epoch 56/100
# 20/20 [==============================] - 4s 220ms/step - loss: 0.1061 - val_loss: 0.1334
# Epoch 57/100
# 20/20 [==============================] - 6s 315ms/step - loss: 0.1057 - val_loss: 0.1321
# Epoch 58/100
# 20/20 [==============================] - 5s 228ms/step - loss: 0.1049 - val_loss: 0.1307
# Epoch 59/100
# 20/20 [==============================] - 4s 221ms/step - loss: 0.1045 - val_loss: 0.1294
# Epoch 60/100
# 20/20 [==============================] - 6s 322ms/step - loss: 0.1040 - val_loss: 0.1281
# Epoch 61/100
# 20/20 [==============================] - 6s 301ms/step - loss: 0.1036 - val_loss: 0.1268
# Epoch 62/100
# 20/20 [==============================] - 7s 321ms/step - loss: 0.1035 - val_loss: 0.1256
# Epoch 63/100
# 20/20 [==============================] - 5s 227ms/step - loss: 0.1023 - val_loss: 0.1243
# Epoch 64/100
# 20/20 [==============================] - 5s 249ms/step - loss: 0.1016 - val_loss: 0.1231
# Epoch 65/100
# 20/20 [==============================] - 6s 273ms/step - loss: 0.1015 - val_loss: 0.1218
# Epoch 66/100
# 20/20 [==============================] - 4s 222ms/step - loss: 0.1012 - val_loss: 0.1206
# Epoch 67/100
# 20/20 [==============================] - 6s 317ms/step - loss: 0.1003 - val_loss: 0.1194
# Epoch 68/100
# 20/20 [==============================] - 4s 221ms/step - loss: 0.0998 - val_loss: 0.1182
# Epoch 69/100
# 20/20 [==============================] - 4s 224ms/step - loss: 0.0997 - val_loss: 0.1170
# Epoch 70/100
# 20/20 [==============================] - 6s 308ms/step - loss: 0.0991 - val_loss: 0.1158
# Epoch 71/100
# 20/20 [==============================] - 4s 218ms/step - loss: 0.0993 - val_loss: 0.1147
# Epoch 72/100
# 20/20 [==============================] - 6s 282ms/step - loss: 0.0979 - val_loss: 0.1136
# Epoch 73/100
# 20/20 [==============================] - 5s 233ms/step - loss: 0.0976 - val_loss: 0.1124
# Epoch 74/100
# 20/20 [==============================] - 4s 223ms/step - loss: 0.0973 - val_loss: 0.1113
# Epoch 75/100
# 20/20 [==============================] - 6s 311ms/step - loss: 0.0965 - val_loss: 0.1102
# Epoch 76/100
# 20/20 [==============================] - 4s 226ms/step - loss: 0.0965 - val_loss: 0.1091
# Epoch 77/100
# 20/20 [==============================] - 5s 235ms/step - loss: 0.0958 - val_loss: 0.1081
# Epoch 78/100
# 20/20 [==============================] - 6s 288ms/step - loss: 0.0957 - val_loss: 0.1070
# Epoch 79/100
# 20/20 [==============================] - 4s 224ms/step - loss: 0.0961 - val_loss: 0.1060
# Epoch 80/100
# 20/20 [==============================] - 6s 324ms/step - loss: 0.0947 - val_loss: 0.1050
# Epoch 81/100
# 20/20 [==============================] - 5s 225ms/step - loss: 0.0951 - val_loss: 0.1040
# Epoch 82/100
# 20/20 [==============================] - 4s 219ms/step - loss: 0.0943 - val_loss: 0.1030
# Epoch 83/100
# 20/20 [==============================] - 6s 305ms/step - loss: 0.0938 - val_loss: 0.1020
# Epoch 84/100
# 20/20 [==============================] - 5s 226ms/step - loss: 0.0939 - val_loss: 0.1010
# Epoch 85/100
# 20/20 [==============================] - 6s 308ms/step - loss: 0.0936 - val_loss: 0.1001
# Epoch 86/100
# 20/20 [==============================] - 4s 221ms/step - loss: 0.0935 - val_loss: 0.0992
# Epoch 87/100
# 20/20 [==============================] - 4s 217ms/step - loss: 0.0933 - val_loss: 0.0983
# Epoch 88/100
# 20/20 [==============================] - 6s 314ms/step - loss: 0.0925 - val_loss: 0.0974
# Epoch 89/100
# 20/20 [==============================] - 4s 220ms/step - loss: 0.0918 - val_loss: 0.0965
# Epoch 90/100
# 20/20 [==============================] - 5s 249ms/step - loss: 0.0918 - val_loss: 0.0956
# Epoch 91/100
# 20/20 [==============================] - 6s 275ms/step - loss: 0.0914 - val_loss: 0.0947
# Epoch 92/100
# 20/20 [==============================] - 4s 222ms/step - loss: 0.0915 - val_loss: 0.0939
# Epoch 93/100
# 20/20 [==============================] - 6s 319ms/step - loss: 0.0912 - val_loss: 0.0930
# Epoch 94/100
# 20/20 [==============================] - 4s 218ms/step - loss: 0.0912 - val_loss: 0.0923
# Epoch 95/100
# 20/20 [==============================] - 4s 224ms/step - loss: 0.0907 - val_loss: 0.0915
# Epoch 96/100
# 20/20 [==============================] - 6s 311ms/step - loss: 0.0908 - val_loss: 0.0908
# Epoch 97/100
# 20/20 [==============================] - 4s 222ms/step - loss: 0.0903 - val_loss: 0.0900
# Epoch 98/100
# 20/20 [==============================] - 6s 289ms/step - loss: 0.0907 - val_loss: 0.0892
# Epoch 99/100
# 20/20 [==============================] - 5s 230ms/step - loss: 0.0905 - val_loss: 0.0885
# Epoch 100/100
# 20/20 [==============================] - 5s 227ms/step - loss: 0.0897 - val_loss: 0.0878

# %%
x_test.shape
# Out:
# (576, 100, 1)

# %%
y_train.shape
# Out:
# (1243, 1)

# %%
len(x_test)
# Out:
# 576

# %%
# 10. Dự báo dữ liệu test, val
y_pred_test = model.predict(x_test)
# Invert normalization min-max
y_pred_invert_norm = scaler.inverse_transform(y_pred_test)
# Out:
# 18/18 [==============================] - 1s 26ms/step

# %%
# 11. Chuẩn hóa dữ liệu y_pred, y_pred_val
# train_predict = scaler.inverse_transform(train_predict)
y_pred = scaler.inverse_transform(y_pred_test)

# %%
len(y_pred_test)
# Out:
# 576

# %%
# 12. Đánh giá độ chính xác thuật toán bằng RMSE, MAE, MAPE
y_pred_test_unscaled = scaler.inverse_transform(y_pred_test.reshape(-1, 1))
y_test_unscaled = scaler.inverse_transform(y_test.reshape(-1, 1))
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Calculate RMSE
test_rmse = np.sqrt(mean_squared_error(y_test_unscaled, y_pred_test_unscaled))

# Calculate MAE
test_mae = mean_absolute_error(y_test_unscaled, y_pred_test_unscaled)

# Calculate MAPE
test_mape = np.mean(np.abs((y_test_unscaled - y_pred_test_unscaled) / y_test_unscaled)) * 100

# Print evaluation metrics
print(f"Testing RMSE: {test_rmse}")
print(f"Testing MAE: {test_mae}")
print(f"Testing MAPE: {test_mape}%")
# Out:
# Testing RMSE: 197.4465018676543
# Testing MAE: 159.75994375016955
# Testing MAPE: 44.58012779801781%

# %%
# 13.Predict cho 30, 60, 90 ngày sau
def predict_days(model, start_input, n_steps, predict_days):
    temp_input = list(start_input)
    temp_input = temp_input[0].tolist()

    lst_output = []
    i = 0
    while i < predict_days:
        if len(temp_input) > n_steps:
            x_input = np.array(temp_input[-n_steps:])
            x_input = x_input.reshape((1, n_steps, 1))
            yhat = model.predict(x_input, verbose=0)
            temp_input.extend(yhat[0].tolist())
            temp_input = temp_input[1:]
            lst_output.extend(yhat.tolist())
            i += 1
        else:
            x_input = np.array(temp_input).reshape((1, n_steps, 1))
            yhat = model.predict(x_input, verbose=0)
            temp_input.extend(yhat[0].tolist())
            lst_output.extend(yhat.tolist())
            i += 1

    return lst_output

# %%
n_steps = 100

# Get the last 100 data points from the test data
x_input = test_data[-100:].reshape(1, -1)

# Predict 30, 60, and 90 days ahead
output_30_days = predict_days(model, x_input, n_steps, 30)
output_60_days = predict_days(model, x_input, n_steps, 60)
output_90_days = predict_days(model, x_input, n_steps, 90)

output_30_days = np.array(output_30_days).reshape(-1, 1)
output_60_days = np.array(output_60_days).reshape(-1, 1)
output_90_days = np.array(output_90_days).reshape(-1, 1)

output_30_days = scaler.inverse_transform(output_30_days)
output_60_days = scaler.inverse_transform(output_60_days)
output_90_days = scaler.inverse_transform(output_90_days)

# %%
# 14. Vẽ hình
# train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
# plt.plot(train_data_index, scaler.inverse_transform(train_data), label='Train')

plt.figure(figsize=(10, 6))

test_data_index = pd.RangeIndex(start=train_size, stop=train_size + test_size, step=1)
plt.plot(test_data_index, scaler.inverse_transform(test_data), label='Test')
plt.plot(test_data_index, y_pred, label='TestPred')

predict_30_days_index = pd.RangeIndex(start=len(df1), stop=len(df1) + 30, step=1)
predict_60_days_index = pd.RangeIndex(start=len(df1), stop=len(df1) + 60, step=1)
predict_90_days_index = pd.RangeIndex(start=len(df1), stop=len(df1) + 90, step=1)

plt.plot(predict_90_days_index, output_90_days, label='Predict90days')
plt.plot(predict_60_days_index, output_60_days, label='Predict60days')
plt.plot(predict_30_days_index, output_30_days, label='Predict30days')

plt.legend()
plt.show()
