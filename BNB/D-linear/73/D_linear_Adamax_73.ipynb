# %% [markdown]
# #Run

# %%
# Thư viện
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from datetime import datetime, timedelta
import matplotlib.pyplot as plt

# %%
#  Model
class moving_avg(nn.Module):
    """
    Moving average block to highlight the trend of time series
    """

    def __init__(self, kernel_size, stride):
        super(moving_avg, self).__init__()
        self.kernel_size = kernel_size
        self.avg = nn.AvgPool1d(kernel_size=kernel_size, stride=stride, padding=0)

    def forward(self, x):
        # padding on the both ends of time series
        front = x[:, 0:1, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        end = x[:, -1:, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        x = torch.cat([front, x, end], dim=1)
        x = self.avg(x.permute(0, 2, 1))
        x = x.permute(0, 2, 1)
        return x
class series_decomp(nn.Module):
    """
    Series decomposition block
    """

    def __init__(self, kernel_size):
        super(series_decomp, self).__init__()
        self.moving_avg = moving_avg(kernel_size, stride=1)

    def forward(self, x):
        moving_mean = self.moving_avg(x)
        res = x - moving_mean
        return res, moving_mean

class Model(nn.Module):
    """
    Paper link: https://arxiv.org/pdf/2205.13504.pdf
    """

    def __init__(self, configs, individual=False):
        """
        individual: Bool, whether shared model among different variates.
        """
        super(Model, self).__init__()
        self.task_name = configs.task_name
        self.seq_len = configs.seq_len
        if self.task_name == 'classification' or self.task_name == 'anomaly_detection' or self.task_name == 'imputation':
            self.pred_len = configs.seq_len
        else:
            self.pred_len = configs.pred_len
        # Series decomposition block from Autoformer
        self.decompsition = series_decomp(configs.moving_avg)
        self.individual = individual
        self.channels = configs.enc_in

        if self.individual:
            self.Linear_Seasonal = nn.ModuleList()
            self.Linear_Trend = nn.ModuleList()

            for i in range(self.channels):
                self.Linear_Seasonal.append(
                    nn.Linear(self.seq_len, self.pred_len))
                self.Linear_Trend.append(
                    nn.Linear(self.seq_len, self.pred_len))

                self.Linear_Seasonal[i].weight = nn.Parameter(
                    (1 / self.seq_len) * torch.ones([self.pred_len, self.seq_len]))
                self.Linear_Trend[i].weight = nn.Parameter(
                    (1 / self.seq_len) * torch.ones([self.pred_len, self.seq_len]))
        else:
            self.Linear_Seasonal = nn.Linear(self.seq_len, self.pred_len)
            self.Linear_Trend = nn.Linear(self.seq_len, self.pred_len)

            self.Linear_Seasonal.weight = nn.Parameter(
                (1 / self.seq_len) * torch.ones([self.pred_len, self.seq_len]))
            self.Linear_Trend.weight = nn.Parameter(
                (1 / self.seq_len) * torch.ones([self.pred_len, self.seq_len]))

        if self.task_name == 'classification':
            self.act = F.gelu
            self.dropout = nn.Dropout(configs.dropout)
            self.projection = nn.Linear(
                configs.enc_in * configs.seq_len, configs.num_class)

    def encoder(self, x):
        seasonal_init, trend_init = self.decompsition(x)
        seasonal_init, trend_init = seasonal_init.permute(
            0, 2, 1), trend_init.permute(0, 2, 1)
        if self.individual:
            seasonal_output = torch.zeros([seasonal_init.size(0), seasonal_init.size(1), self.pred_len],
                                          dtype=seasonal_init.dtype).to(seasonal_init.device)
            trend_output = torch.zeros([trend_init.size(0), trend_init.size(1), self.pred_len],
                                       dtype=trend_init.dtype).to(trend_init.device)
            for i in range(self.channels):
                seasonal_output[:, i, :] = self.Linear_Seasonal[i](
                    seasonal_init[:, i, :])
                trend_output[:, i, :] = self.Linear_Trend[i](
                    trend_init[:, i, :])
        else:
            seasonal_output = self.Linear_Seasonal(seasonal_init)
            trend_output = self.Linear_Trend(trend_init)
        x = seasonal_output + trend_output
        return x.permute(0, 2, 1)

    def forecast(self, x_enc):
        # Encoder
        return self.encoder(x_enc)

    def imputation(self, x_enc):
        # Encoder
        return self.encoder(x_enc)

    def anomaly_detection(self, x_enc):
        # Encoder
        return self.encoder(x_enc)

    def classification(self, x_enc):
        # Encoder
        enc_out = self.encoder(x_enc)
        # Output
        # (batch_size, seq_length * d_model)
        output = enc_out.reshape(enc_out.shape[0], -1)
        # (batch_size, num_classes)
        output = self.projection(output)
        return output

    def forward(self, x_enc, x_mark_enc, x_dec, x_mark_dec, mask=None):
        if self.task_name == 'long_term_forecast' or self.task_name == 'short_term_forecast':
            dec_out = self.forecast(x_enc)
            return dec_out[:, -self.pred_len:, :]  # [B, L, D]
        if self.task_name == 'imputation':
            dec_out = self.imputation(x_enc)
            return dec_out  # [B, L, D]
        if self.task_name == 'anomaly_detection':
            dec_out = self.anomaly_detection(x_enc)
            return dec_out  # [B, L, D]
        if self.task_name == 'classification':
            dec_out = self.classification(x_enc)
            return dec_out  # [B, N]
        return None

# %%
# Đọc dữ liệu từ file đã xử lý
df = pd.read_excel('/content/bnb_processed_data.xlsx')

# %%
# Chọn các cột dữ liệu số
numeric_columns = ['Close']
# Chuyển các giá trị số thành tensor
numeric_data = df[numeric_columns].values.astype(np.float32)
# Mở rộng chiều để phù hợp với đầu vào của mô hình
numeric_data = np.expand_dims(numeric_data, axis=0)

# Lấy dữ liệu cần phân tích
time_series_Close = df['Close']
# Lấy kích thước tập train (7:3)
train_size= int(0.7 * len(time_series_Close))
# Phân chia dữ liệu thành tập huấn luyện và tập kiểm tra (7:3)
train_data = time_series_Close[:train_size]
test_data = time_series_Close[train_size:]
# Chia dữ liệu thành tensor
input_data_train = torch.tensor(numeric_data[:, :len(train_data), :])
input_data_test = torch.tensor(numeric_data[:, len(train_data):, :])
# Lấy dữ liệu 100 ngày gần nhất
recent_100_Close = time_series_Close[-100:]

# Chuyển đổi dữ liệu 100 ngày gần nhất thành numpy array và mở rộng chiều
recent_100_Close_array = recent_100_Close.values.astype(np.float32)
recent_100_Close_array = np.expand_dims(recent_100_Close_array, axis=0)
recent_100_Close_array = np.expand_dims(recent_100_Close_array, axis=-1)
# Chuyển đổi thành tensor
input_data_100day = torch.tensor(recent_100_Close_array)

# In ra để kiểm tra kích thước của các tensor
print("Kích thước tập huấn luyện:", input_data_train.shape)
print("Kích thước tập kiểm tra:", input_data_test.shape)
# Out:
# Kích thước tập huấn luyện: torch.Size([1, 1343, 1])
# Kích thước tập kiểm tra: torch.Size([1, 576, 1])

# %%
class Configs:
    def __init__(self, moving_avg):
        self.task_name = 'long_term_forecast'  # Loại nhiệm vụ: dự đoán cho tương lai
        self.seq_len = 1343  # Độ dài của chuỗi đầu vào
        self.pred_len = 1343  # Độ dài của chuỗi đầu ra dự đoán
        self.enc_in = 64  # Số kênh đầu vào cho bộ mã hóa
        self.num_class = 5  # Số lớp cho bài toán phân loại
        self.dropout = 0.1  # Tỷ lệ dropout
        self.moving_avg = moving_avg

configs = Configs(moving_avg=25)

# Khởi tạo model
model = Model(configs)
model
# Out:
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): moving_avg(
#       (avg): AvgPool1d(kernel_size=(25,), stride=(1,), padding=(0,))
#     )
#   )
#   (Linear_Seasonal): Linear(in_features=1343, out_features=1343, bias=True)
#   (Linear_Trend): Linear(in_features=1343, out_features=1343, bias=True)
# )

# %%
# Xác định hàm mất mát và trình tối ưu hóa
criterion = nn.MSELoss()
optimizer = optim.Adamax(model.parameters(), lr=0.001)  # Có thể điều chỉnh lr theo yêu cầu

# Huấn luyện mô hình
num_epochs = 100  # Số lượng epoch
for epoch in range(num_epochs):
    model.train()  # Chuyển sang chế độ huấn luyện
    optimizer.zero_grad()  # Đặt gradient về 0
    # Feedforward
    outputs = model(input_data_train, None, None, None)
    # Tính toán loss
    loss = criterion(outputs, input_data_train)  # So sánh đầu ra với đầu vào
    # Backpropagation
    loss.backward()  # Tính toán gradient
    optimizer.step()  # Cập nhật trọng số
    # In ra loss sau mỗi epoch
    print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item():.4f}')
# Out:
# Epoch [1/100], Loss: 37451.4844
# Epoch [2/100], Loss: 14462.2383
# Epoch [3/100], Loss: 16907.8359
# Epoch [4/100], Loss: 8641.1318
# Epoch [5/100], Loss: 5527.9175
# Epoch [6/100], Loss: 7461.8599
# Epoch [7/100], Loss: 8368.6865
# Epoch [8/100], Loss: 6262.7310
# Epoch [9/100], Loss: 3207.6660
# Epoch [10/100], Loss: 1570.5507
# Epoch [11/100], Loss: 1830.4692
# Epoch [12/100], Loss: 2893.0002
# Epoch [13/100], Loss: 3483.8101
# Epoch [14/100], Loss: 3126.3242
# Epoch [15/100], Loss: 2187.3945
# Epoch [16/100], Loss: 1329.7438
# Epoch [17/100], Loss: 963.0925
# Epoch [18/100], Loss: 1054.1425
# Epoch [19/100], Loss: 1290.2823
# Epoch [20/100], Loss: 1370.2686
# Epoch [21/100], Loss: 1195.2224
# Epoch [22/100], Loss: 871.9838
# Epoch [23/100], Loss: 585.3757
# Epoch [24/100], Loss: 458.2728
# Epoch [25/100], Loss: 489.2408
# Epoch [26/100], Loss: 583.8207
# Epoch [27/100], Loss: 634.6018
# Epoch [28/100], Loss: 588.7550
# Epoch [29/100], Loss: 466.0124
# Epoch [30/100], Loss: 329.2448
# Epoch [31/100], Loss: 236.9917
# Epoch [32/100], Loss: 210.2113
# Epoch [33/100], Loss: 229.0532
# Epoch [34/100], Loss: 254.1345
# Epoch [35/100], Loss: 254.0310
# Epoch [36/100], Loss: 221.5652
# Epoch [37/100], Loss: 172.0992
# Epoch [38/100], Loss: 129.0175
# Epoch [39/100], Loss: 107.7925
# Epoch [40/100], Loss: 108.2667
# Epoch [41/100], Loss: 117.8820
# Epoch [42/100], Loss: 121.6256
# Epoch [43/100], Loss: 111.4394
# Epoch [44/100], Loss: 89.6572
# Epoch [45/100], Loss: 65.6395
# Epoch [46/100], Loss: 48.9167
# Epoch [47/100], Loss: 43.5482
# Epoch [48/100], Loss: 46.7622
# Epoch [49/100], Loss: 51.8384
# Epoch [50/100], Loss: 52.7165
# Epoch [51/100], Loss: 47.3016
# Epoch [52/100], Loss: 37.7978
# Epoch [53/100], Loss: 28.4817
# Epoch [54/100], Loss: 22.7449
# Epoch [55/100], Loss: 21.2922
# Epoch [56/100], Loss: 22.3107
# Epoch [57/100], Loss: 23.0905
# Epoch [58/100], Loss: 21.8245
# Epoch [59/100], Loss: 18.4787
# Epoch [60/100], Loss: 14.4158
# Epoch [61/100], Loss: 11.2640
# Epoch [62/100], Loss: 9.8720
# Epoch [63/100], Loss: 9.9541
# Epoch [64/100], Loss: 10.4891
# Epoch [65/100], Loss: 10.4697
# Epoch [66/100], Loss: 9.4817
# Epoch [67/100], Loss: 7.8081
# Epoch [68/100], Loss: 6.1040
# Epoch [69/100], Loss: 4.9310
# Epoch [70/100], Loss: 4.4548
# Epoch [71/100], Loss: 4.4428
# Epoch [72/100], Loss: 4.4917
# Epoch [73/100], Loss: 4.2976
# Epoch [74/100], Loss: 3.8016
# Epoch [75/100], Loss: 3.1595
# Epoch [76/100], Loss: 2.5949
# Epoch [77/100], Loss: 2.2508
# Epoch [78/100], Loss: 2.1230
# Epoch [79/100], Loss: 2.0953
# Epoch [80/100], Loss: 2.0306
# Epoch [81/100], Loss: 1.8540
# Epoch [82/100], Loss: 1.5815
# Epoch [83/100], Loss: 1.2916
# Epoch [84/100], Loss: 1.0674
# Epoch [85/100], Loss: 0.9480
# Epoch [86/100], Loss: 0.9145
# Epoch [87/100], Loss: 0.9111
# Epoch [88/100], Loss: 0.8821
# Epoch [89/100], Loss: 0.8027
# Epoch [90/100], Loss: 0.6854
# Epoch [91/100], Loss: 0.5657
# Epoch [92/100], Loss: 0.4761
# Epoch [93/100], Loss: 0.4284
# Epoch [94/100], Loss: 0.4105
# Epoch [95/100], Loss: 0.3983
# Epoch [96/100], Loss: 0.3721
# Epoch [97/100], Loss: 0.3277
# Epoch [98/100], Loss: 0.2758
# Epoch [99/100], Loss: 0.2320
# Epoch [100/100], Loss: 0.2059

# %%
# Dự báo cho tập test
# # Chuyển sang chế độ đánh giá
model.eval()
# Không cần tính gradient trong quá trình dự báo
with torch.no_grad():
    input_data_train = input_data_train.clone()  # Tạo một bản sao của dữ liệu đầu vào để cập nhật dự báo
    predicted_test = []  # Danh sách dự báo cho các ngày tiếp theo
    for i in range(len(test_data)):  # Dự báo cho tập test
        # Dự báo cho ngày hiện tại
        output = model(input_data_train, None, None, None)
        # Lưu dự báo của ngày hiện tại
        predicted_test.append(output[:, -1, :])  # Lấy dự báo cho ngày cuối cùng trong chuỗi thời gian
        # Cập nhật dữ liệu đầu vào cho ngày tiếp theo
        input_data_train = torch.cat([input_data_train[:, :, 1:], output], dim=2)
    # In ra dự báo cho tập test
    print("Predicted Output for data test:")
    for i in range(len(test_data)):
        # In ra ngày tương ứng với dự báo
        print(f"Day  Predicted: {predicted_test[i][0]}")
# Out:
# Predicted Output for data test:
# Day  Predicted: tensor([320.2112])
# Day  Predicted: tensor([320.0331])
# Day  Predicted: tensor([319.8382])
# Day  Predicted: tensor([319.6425])
# Day  Predicted: tensor([319.4468])
# Day  Predicted: tensor([319.2513])
# Day  Predicted: tensor([319.0558])
# Day  Predicted: tensor([318.8606])
# Day  Predicted: tensor([318.6655])
# Day  Predicted: tensor([318.4704])
# Day  Predicted: tensor([318.2755])
# Day  Predicted: tensor([318.0807])
# Day  Predicted: tensor([317.8860])
# Day  Predicted: tensor([317.6914])
# Day  Predicted: tensor([317.4969])
# Day  Predicted: tensor([317.3026])
# Day  Predicted: tensor([317.1084])
# Day  Predicted: tensor([316.9143])
# Day  Predicted: tensor([316.7203])
# Day  Predicted: tensor([316.5265])
# Day  Predicted: tensor([316.3327])
# Day  Predicted: tensor([316.1391])
# Day  Predicted: tensor([315.9456])
# Day  Predicted: tensor([315.7522])
# Day  Predicted: tensor([315.5589])
# Day  Predicted: tensor([315.3658])
# Day  Predicted: tensor([315.1728])
# Day  Predicted: tensor([314.9799])
# Day  Predicted: tensor([314.7871])
# Day  Predicted: tensor([314.5944])
# Day  Predicted: tensor([314.4018])
# Day  Predicted: tensor([314.2094])
# Day  Predicted: tensor([314.0170])
# Day  Predicted: tensor([313.8248])
# Day  Predicted: tensor([313.6328])
# Day  Predicted: tensor([313.4408])
# Day  Predicted: tensor([313.2489])
# Day  Predicted: tensor([313.0572])
# Day  Predicted: tensor([312.8656])
# Day  Predicted: tensor([312.6740])
# Day  Predicted: tensor([312.4827])
# Day  Predicted: tensor([312.2914])
# Day  Predicted: tensor([312.1002])
# Day  Predicted: tensor([311.9092])
# Day  Predicted: tensor([311.7183])
# Day  Predicted: tensor([311.5275])
# Day  Predicted: tensor([311.3368])
# Day  Predicted: tensor([311.1462])
# Day  Predicted: tensor([310.9557])
# Day  Predicted: tensor([310.7654])
# Day  Predicted: tensor([310.5752])
# Day  Predicted: tensor([310.3850])
# Day  Predicted: tensor([310.1951])
# Day  Predicted: tensor([310.0052])
# Day  Predicted: tensor([309.8155])
# Day  Predicted: tensor([309.6258])
# Day  Predicted: tensor([309.4363])
# Day  Predicted: tensor([309.2469])
# Day  Predicted: tensor([309.0576])
# Day  Predicted: tensor([308.8683])
# Day  Predicted: tensor([308.6793])
# Day  Predicted: tensor([308.4904])
# Day  Predicted: tensor([308.3015])
# Day  Predicted: tensor([308.1128])
# Day  Predicted: tensor([307.9242])
# Day  Predicted: tensor([307.7357])
# Day  Predicted: tensor([307.5473])
# Day  Predicted: tensor([307.3591])
# Day  Predicted: tensor([307.1709])
# Day  Predicted: tensor([306.9828])
# Day  Predicted: tensor([306.7949])
# Day  Predicted: tensor([306.6071])
# Day  Predicted: tensor([306.4195])
# Day  Predicted: tensor([306.2319])
# Day  Predicted: tensor([306.0444])
# Day  Predicted: tensor([305.8571])
# Day  Predicted: tensor([305.6699])
# Day  Predicted: tensor([305.4827])
# Day  Predicted: tensor([305.2957])
# Day  Predicted: tensor([305.1089])
# Day  Predicted: tensor([304.9221])
# Day  Predicted: tensor([304.7354])
# Day  Predicted: tensor([304.5489])
# Day  Predicted: tensor([304.3625])
# Day  Predicted: tensor([304.1761])
# Day  Predicted: tensor([303.9899])
# Day  Predicted: tensor([303.8038])
# Day  Predicted: tensor([303.6178])
# Day  Predicted: tensor([303.4319])
# Day  Predicted: tensor([303.2462])
# Day  Predicted: tensor([303.0606])
# Day  Predicted: tensor([302.8750])
# Day  Predicted: tensor([302.6896])
# Day  Predicted: tensor([302.5044])
# Day  Predicted: tensor([302.3191])
# Day  Predicted: tensor([302.1341])
# Day  Predicted: tensor([301.9491])
# Day  Predicted: tensor([301.7643])
# Day  Predicted: tensor([301.5795])
# Day  Predicted: tensor([301.3949])
# Day  Predicted: tensor([301.2104])
# Day  Predicted: tensor([301.0260])
# Day  Predicted: tensor([300.8418])
# Day  Predicted: tensor([300.6576])
# Day  Predicted: tensor([300.4735])
# Day  Predicted: tensor([300.2896])
# Day  Predicted: tensor([300.1057])
# Day  Predicted: tensor([299.9220])
# Day  Predicted: tensor([299.7384])
# Day  Predicted: tensor([299.5549])
# Day  Predicted: tensor([299.3715])
# Day  Predicted: tensor([299.1882])
# Day  Predicted: tensor([299.0050])
# Day  Predicted: tensor([298.8220])
# Day  Predicted: tensor([298.6391])
# Day  Predicted: tensor([298.4562])
# Day  Predicted: tensor([298.2735])
# Day  Predicted: tensor([298.0909])
# Day  Predicted: tensor([297.9084])
# Day  Predicted: tensor([297.7260])
# Day  Predicted: tensor([297.5438])
# Day  Predicted: tensor([297.3616])
# Day  Predicted: tensor([297.1796])
# Day  Predicted: tensor([296.9977])
# Day  Predicted: tensor([296.8158])
# Day  Predicted: tensor([296.6341])
# Day  Predicted: tensor([296.4525])
# Day  Predicted: tensor([296.2710])
# Day  Predicted: tensor([296.0896])
# Day  Predicted: tensor([295.9083])
# Day  Predicted: tensor([295.7271])
# Day  Predicted: tensor([295.5461])
# Day  Predicted: tensor([295.3652])
# Day  Predicted: tensor([295.1843])
# Day  Predicted: tensor([295.0037])
# Day  Predicted: tensor([294.8230])
# Day  Predicted: tensor([294.6425])
# Day  Predicted: tensor([294.4622])
# Day  Predicted: tensor([294.2818])
# Day  Predicted: tensor([294.1017])
# Day  Predicted: tensor([293.9216])
# Day  Predicted: tensor([293.7417])
# Day  Predicted: tensor([293.5619])
# Day  Predicted: tensor([293.3821])
# Day  Predicted: tensor([293.2025])
# Day  Predicted: tensor([293.0230])
# Day  Predicted: tensor([292.8436])
# Day  Predicted: tensor([292.6643])
# Day  Predicted: tensor([292.4851])
# Day  Predicted: tensor([292.3061])
# Day  Predicted: tensor([292.1271])
# Day  Predicted: tensor([291.9482])
# Day  Predicted: tensor([291.7695])
# Day  Predicted: tensor([291.5908])
# Day  Predicted: tensor([291.4123])
# Day  Predicted: tensor([291.2339])
# Day  Predicted: tensor([291.0556])
# Day  Predicted: tensor([290.8774])
# Day  Predicted: tensor([290.6993])
# Day  Predicted: tensor([290.5213])
# Day  Predicted: tensor([290.3434])
# Day  Predicted: tensor([290.1656])
# Day  Predicted: tensor([289.9880])
# Day  Predicted: tensor([289.8104])
# Day  Predicted: tensor([289.6330])
# Day  Predicted: tensor([289.4557])
# Day  Predicted: tensor([289.2784])
# Day  Predicted: tensor([289.1013])
# Day  Predicted: tensor([288.9243])
# Day  Predicted: tensor([288.7474])
# Day  Predicted: tensor([288.5706])
# Day  Predicted: tensor([288.3940])
# Day  Predicted: tensor([288.2174])
# Day  Predicted: tensor([288.0409])
# Day  Predicted: tensor([287.8645])
# Day  Predicted: tensor([287.6882])
# Day  Predicted: tensor([287.5121])
# Day  Predicted: tensor([287.3361])
# Day  Predicted: tensor([287.1601])
# Day  Predicted: tensor([286.9843])
# Day  Predicted: tensor([286.8086])
# Day  Predicted: tensor([286.6330])
# Day  Predicted: tensor([286.4575])
# Day  Predicted: tensor([286.2821])
# Day  Predicted: tensor([286.1068])
# Day  Predicted: tensor([285.9316])
# Day  Predicted: tensor([285.7565])
# Day  Predicted: tensor([285.5816])
# Day  Predicted: tensor([285.4067])
# Day  Predicted: tensor([285.2320])
# Day  Predicted: tensor([285.0573])
# Day  Predicted: tensor([284.8828])
# Day  Predicted: tensor([284.7083])
# Day  Predicted: tensor([284.5340])
# Day  Predicted: tensor([284.3598])
# Day  Predicted: tensor([284.1856])
# Day  Predicted: tensor([284.0117])
# Day  Predicted: tensor([283.8377])
# Day  Predicted: tensor([283.6640])
# Day  Predicted: tensor([283.4903])
# Day  Predicted: tensor([283.3167])
# Day  Predicted: tensor([283.1432])
# Day  Predicted: tensor([282.9698])
# Day  Predicted: tensor([282.7965])
# Day  Predicted: tensor([282.6234])
# Day  Predicted: tensor([282.4503])
# Day  Predicted: tensor([282.2773])
# Day  Predicted: tensor([282.1045])
# Day  Predicted: tensor([281.9318])
# Day  Predicted: tensor([281.7592])
# Day  Predicted: tensor([281.5866])
# Day  Predicted: tensor([281.4142])
# Day  Predicted: tensor([281.2419])
# Day  Predicted: tensor([281.0696])
# Day  Predicted: tensor([280.8975])
# Day  Predicted: tensor([280.7256])
# Day  Predicted: tensor([280.5536])
# Day  Predicted: tensor([280.3818])
# Day  Predicted: tensor([280.2101])
# Day  Predicted: tensor([280.0385])
# Day  Predicted: tensor([279.8671])
# Day  Predicted: tensor([279.6957])
# Day  Predicted: tensor([279.5244])
# Day  Predicted: tensor([279.3533])
# Day  Predicted: tensor([279.1822])
# Day  Predicted: tensor([279.0113])
# Day  Predicted: tensor([278.8404])
# Day  Predicted: tensor([278.6696])
# Day  Predicted: tensor([278.4990])
# Day  Predicted: tensor([278.3285])
# Day  Predicted: tensor([278.1580])
# Day  Predicted: tensor([277.9877])
# Day  Predicted: tensor([277.8174])
# Day  Predicted: tensor([277.6473])
# Day  Predicted: tensor([277.4773])
# Day  Predicted: tensor([277.3074])
# Day  Predicted: tensor([277.1376])
# Day  Predicted: tensor([276.9678])
# Day  Predicted: tensor([276.7982])
# Day  Predicted: tensor([276.6288])
# Day  Predicted: tensor([276.4594])
# Day  Predicted: tensor([276.2900])
# Day  Predicted: tensor([276.1209])
# Day  Predicted: tensor([275.9518])
# Day  Predicted: tensor([275.7827])
# Day  Predicted: tensor([275.6139])
# Day  Predicted: tensor([275.4451])
# Day  Predicted: tensor([275.2764])
# Day  Predicted: tensor([275.1078])
# Day  Predicted: tensor([274.9394])
# Day  Predicted: tensor([274.7710])
# Day  Predicted: tensor([274.6027])
# Day  Predicted: tensor([274.4346])
# Day  Predicted: tensor([274.2665])
# Day  Predicted: tensor([274.0985])
# Day  Predicted: tensor([273.9307])
# Day  Predicted: tensor([273.7629])
# Day  Predicted: tensor([273.5953])
# Day  Predicted: tensor([273.4277])
# Day  Predicted: tensor([273.2603])
# Day  Predicted: tensor([273.0930])
# Day  Predicted: tensor([272.9257])
# Day  Predicted: tensor([272.7586])
# Day  Predicted: tensor([272.5915])
# Day  Predicted: tensor([272.4246])
# Day  Predicted: tensor([272.2577])
# Day  Predicted: tensor([272.0910])
# Day  Predicted: tensor([271.9244])
# Day  Predicted: tensor([271.7578])
# Day  Predicted: tensor([271.5914])
# Day  Predicted: tensor([271.4251])
# Day  Predicted: tensor([271.2589])
# Day  Predicted: tensor([271.0927])
# Day  Predicted: tensor([270.9267])
# Day  Predicted: tensor([270.7608])
# Day  Predicted: tensor([270.5950])
# Day  Predicted: tensor([270.4292])
# Day  Predicted: tensor([270.2636])
# Day  Predicted: tensor([270.0981])
# Day  Predicted: tensor([269.9327])
# Day  Predicted: tensor([269.7673])
# Day  Predicted: tensor([269.6022])
# Day  Predicted: tensor([269.4370])
# Day  Predicted: tensor([269.2721])
# Day  Predicted: tensor([269.1071])
# Day  Predicted: tensor([268.9423])
# Day  Predicted: tensor([268.7776])
# Day  Predicted: tensor([268.6130])
# Day  Predicted: tensor([268.4485])
# Day  Predicted: tensor([268.2841])
# Day  Predicted: tensor([268.1197])
# Day  Predicted: tensor([267.9556])
# Day  Predicted: tensor([267.7914])
# Day  Predicted: tensor([267.6274])
# Day  Predicted: tensor([267.4635])
# Day  Predicted: tensor([267.2997])
# Day  Predicted: tensor([267.1360])
# Day  Predicted: tensor([266.9724])
# Day  Predicted: tensor([266.8088])
# Day  Predicted: tensor([266.6454])
# Day  Predicted: tensor([266.4821])
# Day  Predicted: tensor([266.3190])
# Day  Predicted: tensor([266.1558])
# Day  Predicted: tensor([265.9928])
# Day  Predicted: tensor([265.8299])
# Day  Predicted: tensor([265.6671])
# Day  Predicted: tensor([265.5044])
# Day  Predicted: tensor([265.3418])
# Day  Predicted: tensor([265.1792])
# Day  Predicted: tensor([265.0168])
# Day  Predicted: tensor([264.8545])
# Day  Predicted: tensor([264.6923])
# Day  Predicted: tensor([264.5302])
# Day  Predicted: tensor([264.3681])
# Day  Predicted: tensor([264.2062])
# Day  Predicted: tensor([264.0444])
# Day  Predicted: tensor([263.8827])
# Day  Predicted: tensor([263.7210])
# Day  Predicted: tensor([263.5595])
# Day  Predicted: tensor([263.3981])
# Day  Predicted: tensor([263.2368])
# Day  Predicted: tensor([263.0755])
# Day  Predicted: tensor([262.9144])
# Day  Predicted: tensor([262.7534])
# Day  Predicted: tensor([262.5924])
# Day  Predicted: tensor([262.4316])
# Day  Predicted: tensor([262.2708])
# Day  Predicted: tensor([262.1102])
# Day  Predicted: tensor([261.9496])
# Day  Predicted: tensor([261.7892])
# Day  Predicted: tensor([261.6288])
# Day  Predicted: tensor([261.4686])
# Day  Predicted: tensor([261.3084])
# Day  Predicted: tensor([261.1484])
# Day  Predicted: tensor([260.9885])
# Day  Predicted: tensor([260.8286])
# Day  Predicted: tensor([260.6688])
# Day  Predicted: tensor([260.5092])
# Day  Predicted: tensor([260.3496])
# Day  Predicted: tensor([260.1901])
# Day  Predicted: tensor([260.0307])
# Day  Predicted: tensor([259.8715])
# Day  Predicted: tensor([259.7123])
# Day  Predicted: tensor([259.5532])
# Day  Predicted: tensor([259.3942])
# Day  Predicted: tensor([259.2353])
# Day  Predicted: tensor([259.0766])
# Day  Predicted: tensor([258.9178])
# Day  Predicted: tensor([258.7592])
# Day  Predicted: tensor([258.6008])
# Day  Predicted: tensor([258.4424])
# Day  Predicted: tensor([258.2841])
# Day  Predicted: tensor([258.1259])
# Day  Predicted: tensor([257.9677])
# Day  Predicted: tensor([257.8097])
# Day  Predicted: tensor([257.6518])
# Day  Predicted: tensor([257.4939])
# Day  Predicted: tensor([257.3362])
# Day  Predicted: tensor([257.1786])
# Day  Predicted: tensor([257.0211])
# Day  Predicted: tensor([256.8636])
# Day  Predicted: tensor([256.7063])
# Day  Predicted: tensor([256.5490])
# Day  Predicted: tensor([256.3919])
# Day  Predicted: tensor([256.2348])
# Day  Predicted: tensor([256.0779])
# Day  Predicted: tensor([255.9210])
# Day  Predicted: tensor([255.7642])
# Day  Predicted: tensor([255.6076])
# Day  Predicted: tensor([255.4510])
# Day  Predicted: tensor([255.2945])
# Day  Predicted: tensor([255.1381])
# Day  Predicted: tensor([254.9818])
# Day  Predicted: tensor([254.8256])
# Day  Predicted: tensor([254.6695])
# Day  Predicted: tensor([254.5135])
# Day  Predicted: tensor([254.3576])
# Day  Predicted: tensor([254.2018])
# Day  Predicted: tensor([254.0461])
# Day  Predicted: tensor([253.8904])
# Day  Predicted: tensor([253.7349])
# Day  Predicted: tensor([253.5795])
# Day  Predicted: tensor([253.4241])
# Day  Predicted: tensor([253.2689])
# Day  Predicted: tensor([253.1138])
# Day  Predicted: tensor([252.9587])
# Day  Predicted: tensor([252.8037])
# Day  Predicted: tensor([252.6489])
# Day  Predicted: tensor([252.4941])
# Day  Predicted: tensor([252.3394])
# Day  Predicted: tensor([252.1848])
# Day  Predicted: tensor([252.0303])
# Day  Predicted: tensor([251.8759])
# Day  Predicted: tensor([251.7217])
# Day  Predicted: tensor([251.5674])
# Day  Predicted: tensor([251.4133])
# Day  Predicted: tensor([251.2593])
# Day  Predicted: tensor([251.1054])
# Day  Predicted: tensor([250.9515])
# Day  Predicted: tensor([250.7978])
# Day  Predicted: tensor([250.6441])
# Day  Predicted: tensor([250.4906])
# Day  Predicted: tensor([250.3372])
# Day  Predicted: tensor([250.1838])
# Day  Predicted: tensor([250.0305])
# Day  Predicted: tensor([249.8774])
# Day  Predicted: tensor([249.7243])
# Day  Predicted: tensor([249.5713])
# Day  Predicted: tensor([249.4184])
# Day  Predicted: tensor([249.2656])
# Day  Predicted: tensor([249.1129])
# Day  Predicted: tensor([248.9603])
# Day  Predicted: tensor([248.8078])
# Day  Predicted: tensor([248.6553])
# Day  Predicted: tensor([248.5030])
# Day  Predicted: tensor([248.3508])
# Day  Predicted: tensor([248.1986])
# Day  Predicted: tensor([248.0465])
# Day  Predicted: tensor([247.8946])
# Day  Predicted: tensor([247.7427])
# Day  Predicted: tensor([247.5909])
# Day  Predicted: tensor([247.4392])
# Day  Predicted: tensor([247.2876])
# Day  Predicted: tensor([247.1361])
# Day  Predicted: tensor([246.9847])
# Day  Predicted: tensor([246.8334])
# Day  Predicted: tensor([246.6822])
# Day  Predicted: tensor([246.5310])
# Day  Predicted: tensor([246.3800])
# Day  Predicted: tensor([246.2291])
# Day  Predicted: tensor([246.0782])
# Day  Predicted: tensor([245.9274])
# Day  Predicted: tensor([245.7767])
# Day  Predicted: tensor([245.6262])
# Day  Predicted: tensor([245.4757])
# Day  Predicted: tensor([245.3253])
# Day  Predicted: tensor([245.1750])
# Day  Predicted: tensor([245.0248])
# Day  Predicted: tensor([244.8747])
# Day  Predicted: tensor([244.7246])
# Day  Predicted: tensor([244.5747])
# Day  Predicted: tensor([244.4249])
# Day  Predicted: tensor([244.2751])
# Day  Predicted: tensor([244.1254])
# Day  Predicted: tensor([243.9759])
# Day  Predicted: tensor([243.8264])
# Day  Predicted: tensor([243.6770])
# Day  Predicted: tensor([243.5277])
# Day  Predicted: tensor([243.3784])
# Day  Predicted: tensor([243.2294])
# Day  Predicted: tensor([243.0803])
# Day  Predicted: tensor([242.9314])
# Day  Predicted: tensor([242.7825])
# Day  Predicted: tensor([242.6338])
# Day  Predicted: tensor([242.4851])
# Day  Predicted: tensor([242.3366])
# Day  Predicted: tensor([242.1881])
# Day  Predicted: tensor([242.0397])
# Day  Predicted: tensor([241.8914])
# Day  Predicted: tensor([241.7432])
# Day  Predicted: tensor([241.5950])
# Day  Predicted: tensor([241.4470])
# Day  Predicted: tensor([241.2991])
# Day  Predicted: tensor([241.1512])
# Day  Predicted: tensor([241.0035])
# Day  Predicted: tensor([240.8558])
# Day  Predicted: tensor([240.7082])
# Day  Predicted: tensor([240.5607])
# Day  Predicted: tensor([240.4133])
# Day  Predicted: tensor([240.2660])
# Day  Predicted: tensor([240.1188])
# Day  Predicted: tensor([239.9717])
# Day  Predicted: tensor([239.8246])
# Day  Predicted: tensor([239.6777])
# Day  Predicted: tensor([239.5308])
# Day  Predicted: tensor([239.3841])
# Day  Predicted: tensor([239.2374])
# Day  Predicted: tensor([239.0908])
# Day  Predicted: tensor([238.9443])
# Day  Predicted: tensor([238.7979])
# Day  Predicted: tensor([238.6516])
# Day  Predicted: tensor([238.5053])
# Day  Predicted: tensor([238.3592])
# Day  Predicted: tensor([238.2131])
# Day  Predicted: tensor([238.0672])
# Day  Predicted: tensor([237.9213])
# Day  Predicted: tensor([237.7755])
# Day  Predicted: tensor([237.6298])
# Day  Predicted: tensor([237.4842])
# Day  Predicted: tensor([237.3387])
# Day  Predicted: tensor([237.1932])
# Day  Predicted: tensor([237.0479])
# Day  Predicted: tensor([236.9026])
# Day  Predicted: tensor([236.7575])
# Day  Predicted: tensor([236.6124])
# Day  Predicted: tensor([236.4674])
# Day  Predicted: tensor([236.3225])
# Day  Predicted: tensor([236.1777])
# Day  Predicted: tensor([236.0330])
# Day  Predicted: tensor([235.8883])
# Day  Predicted: tensor([235.7438])
# Day  Predicted: tensor([235.5993])
# Day  Predicted: tensor([235.4550])
# Day  Predicted: tensor([235.3107])
# Day  Predicted: tensor([235.1665])
# Day  Predicted: tensor([235.0224])
# Day  Predicted: tensor([234.8783])
# Day  Predicted: tensor([234.7344])
# Day  Predicted: tensor([234.5906])
# Day  Predicted: tensor([234.4468])
# Day  Predicted: tensor([234.3031])
# Day  Predicted: tensor([234.1596])
# Day  Predicted: tensor([234.0161])
# Day  Predicted: tensor([233.8726])
# Day  Predicted: tensor([233.7293])
# Day  Predicted: tensor([233.5861])
# Day  Predicted: tensor([233.4429])
# Day  Predicted: tensor([233.2999])
# Day  Predicted: tensor([233.1570])
# Day  Predicted: tensor([233.0141])
# Day  Predicted: tensor([232.8712])
# Day  Predicted: tensor([232.7286])
# Day  Predicted: tensor([232.5859])
# Day  Predicted: tensor([232.4434])
# Day  Predicted: tensor([232.3009])
# Day  Predicted: tensor([232.1586])
# Day  Predicted: tensor([232.0163])
# Day  Predicted: tensor([231.8741])
# Day  Predicted: tensor([231.7320])
# Day  Predicted: tensor([231.5900])
# Day  Predicted: tensor([231.4481])
# Day  Predicted: tensor([231.3063])
# Day  Predicted: tensor([231.1645])
# Day  Predicted: tensor([231.0228])
# Day  Predicted: tensor([230.8813])
# Day  Predicted: tensor([230.7398])
# Day  Predicted: tensor([230.5984])
# Day  Predicted: tensor([230.4571])
# Day  Predicted: tensor([230.3158])
# Day  Predicted: tensor([230.1747])
# Day  Predicted: tensor([230.0336])
# Day  Predicted: tensor([229.8926])
# Day  Predicted: tensor([229.7517])
# Day  Predicted: tensor([229.6109])
# Day  Predicted: tensor([229.4702])
# Day  Predicted: tensor([229.3296])
# Day  Predicted: tensor([229.1890])
# Day  Predicted: tensor([229.0486])
# Day  Predicted: tensor([228.9082])
# Day  Predicted: tensor([228.7679])
# Day  Predicted: tensor([228.6277])
# Day  Predicted: tensor([228.4876])
# Day  Predicted: tensor([228.3475])
# Day  Predicted: tensor([228.2076])
# Day  Predicted: tensor([228.0677])
# Day  Predicted: tensor([227.9280])
# Day  Predicted: tensor([227.7883])
# Day  Predicted: tensor([227.6487])
# Day  Predicted: tensor([227.5091])
# Day  Predicted: tensor([227.3697])
# Day  Predicted: tensor([227.2304])
# Day  Predicted: tensor([227.0911])
# Day  Predicted: tensor([226.9519])
# Day  Predicted: tensor([226.8128])
# Day  Predicted: tensor([226.6738])
# Day  Predicted: tensor([226.5349])
# Day  Predicted: tensor([226.3960])
# Day  Predicted: tensor([226.2572])
# Day  Predicted: tensor([226.1186])
# Day  Predicted: tensor([225.9800])
# Day  Predicted: tensor([225.8415])
# Day  Predicted: tensor([225.7031])
# Day  Predicted: tensor([225.5648])
# Day  Predicted: tensor([225.4265])
# Day  Predicted: tensor([225.2883])
# Day  Predicted: tensor([225.1503])

# %%
class Configs:
    def __init__(self, moving_avg):
        self.task_name = 'long_term_forecast'  # Loại nhiệm vụ: dự đoán cho tương lai
        self.seq_len = 100  # Độ dài của chuỗi đầu vào
        self.pred_len = 100  # Độ dài của chuỗi đầu ra dự đoán
        self.enc_in = 64  # Số kênh đầu vào cho bộ mã hóa
        self.num_class = 5  # Số lớp cho bài toán phân loại
        self.dropout = 0.1  # Tỷ lệ dropout
        self.moving_avg = moving_avg

configs = Configs(moving_avg=25)

# Khởi tạo model
model_100 = Model(configs)
model_100
# Out:
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): moving_avg(
#       (avg): AvgPool1d(kernel_size=(25,), stride=(1,), padding=(0,))
#     )
#   )
#   (Linear_Seasonal): Linear(in_features=100, out_features=100, bias=True)
#   (Linear_Trend): Linear(in_features=100, out_features=100, bias=True)
# )

# %%
# Xác định hàm mất mát và trình tối ưu hóa
criterion = nn.MSELoss()
optimizer = optim.Adam(model_100.parameters(), lr=0.001)  # Có thể điều chỉnh lr theo yêu cầu
# Huấn luyện mô hình
num_epochs = 100  # Số lượng epoch
for epoch in range(num_epochs):
    model_100.train()  # Chuyển sang chế độ huấn luyện
    optimizer.zero_grad()  # Đặt gradient về 0
    # Feedforward
    outputs = model_100(input_data_100day, None, None, None)
    # Tính toán loss
    loss = criterion(outputs, input_data_100day)  # So sánh đầu ra với đầu vào
    # Backpropagation
    loss.backward()  # Tính toán gradient
    optimizer.step()  # Cập nhật trọng số
    # In ra loss sau mỗi epoch
    print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item():.4f}')
# Out:
# Epoch [1/100], Loss: 4563.0488
# Epoch [2/100], Loss: 2114.9385
# Epoch [3/100], Loss: 990.9271
# Epoch [4/100], Loss: 653.8051
# Epoch [5/100], Loss: 895.5937
# Epoch [6/100], Loss: 1125.0221
# Epoch [7/100], Loss: 1158.1882
# Epoch [8/100], Loss: 1059.2310
# Epoch [9/100], Loss: 901.2528
# Epoch [10/100], Loss: 662.9827
# Epoch [11/100], Loss: 388.1222
# Epoch [12/100], Loss: 208.4925
# Epoch [13/100], Loss: 199.6413
# Epoch [14/100], Loss: 305.2870
# Epoch [15/100], Loss: 405.0101
# Epoch [16/100], Loss: 429.8075
# Epoch [17/100], Loss: 390.2693
# Epoch [18/100], Loss: 322.5489
# Epoch [19/100], Loss: 244.7955
# Epoch [20/100], Loss: 168.9770
# Epoch [21/100], Loss: 117.5680
# Epoch [22/100], Loss: 106.5746
# Epoch [23/100], Loss: 124.0728
# Epoch [24/100], Loss: 140.7167
# Epoch [25/100], Loss: 141.4642
# Epoch [26/100], Loss: 133.8482
# Epoch [27/100], Loss: 125.7989
# Epoch [28/100], Loss: 111.3762
# Epoch [29/100], Loss: 84.7969
# Epoch [30/100], Loss: 56.6160
# Epoch [31/100], Loss: 44.1690
# Epoch [32/100], Loss: 49.7068
# Epoch [33/100], Loss: 58.3625
# Epoch [34/100], Loss: 57.7222
# Epoch [35/100], Loss: 50.2028
# Epoch [36/100], Loss: 44.0874
# Epoch [37/100], Loss: 40.8219
# Epoch [38/100], Loss: 36.2946
# Epoch [39/100], Loss: 29.3745
# Epoch [40/100], Loss: 23.3521
# Epoch [41/100], Loss: 20.6736
# Epoch [42/100], Loss: 20.6148
# Epoch [43/100], Loss: 21.3627
# Epoch [44/100], Loss: 21.3509
# Epoch [45/100], Loss: 19.3381
# Epoch [46/100], Loss: 15.6113
# Epoch [47/100], Loss: 12.4616
# Epoch [48/100], Loss: 11.5502
# Epoch [49/100], Loss: 11.6161
# Epoch [50/100], Loss: 10.4976
# Epoch [51/100], Loss: 8.3811
# Epoch [52/100], Loss: 7.1806
# Epoch [53/100], Loss: 7.4817
# Epoch [54/100], Loss: 7.9139
# Epoch [55/100], Loss: 7.2473
# Epoch [56/100], Loss: 5.7287
# Epoch [57/100], Loss: 4.3945
# Epoch [58/100], Loss: 3.8901
# Epoch [59/100], Loss: 3.9777
# Epoch [60/100], Loss: 3.9245
# Epoch [61/100], Loss: 3.4291
# Epoch [62/100], Loss: 2.9522
# Epoch [63/100], Loss: 2.8692
# Epoch [64/100], Loss: 2.8141
# Epoch [65/100], Loss: 2.3658
# Epoch [66/100], Loss: 1.7984
# Epoch [67/100], Loss: 1.5640
# Epoch [68/100], Loss: 1.5819
# Epoch [69/100], Loss: 1.5501
# Epoch [70/100], Loss: 1.4456
# Epoch [71/100], Loss: 1.3403
# Epoch [72/100], Loss: 1.1799
# Epoch [73/100], Loss: 0.9702
# Epoch [74/100], Loss: 0.8182
# Epoch [75/100], Loss: 0.7418
# Epoch [76/100], Loss: 0.6974
# Epoch [77/100], Loss: 0.6881
# Epoch [78/100], Loss: 0.6768
# Epoch [79/100], Loss: 0.5888
# Epoch [80/100], Loss: 0.4685
# Epoch [81/100], Loss: 0.4136
# Epoch [82/100], Loss: 0.3958
# Epoch [83/100], Loss: 0.3477
# Epoch [84/100], Loss: 0.3046
# Epoch [85/100], Loss: 0.3031
# Epoch [86/100], Loss: 0.2970
# Epoch [87/100], Loss: 0.2567
# Epoch [88/100], Loss: 0.2097
# Epoch [89/100], Loss: 0.1758
# Epoch [90/100], Loss: 0.1612
# Epoch [91/100], Loss: 0.1664
# Epoch [92/100], Loss: 0.1613
# Epoch [93/100], Loss: 0.1290
# Epoch [94/100], Loss: 0.1058
# Epoch [95/100], Loss: 0.1093
# Epoch [96/100], Loss: 0.1049
# Epoch [97/100], Loss: 0.0825
# Epoch [98/100], Loss: 0.0712
# Epoch [99/100], Loss: 0.0726
# Epoch [100/100], Loss: 0.0658

# %%
# Dự báo cho 30/60/90
# # Chuyển sang chế độ đánh giá
model_100.eval()

# Không cần tính gradient trong quá trình dự báo
with torch.no_grad():
    input_data_future = input_data_100day.clone()  # Tạo một bản sao của dữ liệu đầu vào để cập nhật dự báo
    predicted_90 = []  # Danh sách dự báo cho các ngày tiếp theo
    for i in range(90):  # Dự báo cho tập test
        # Dự báo cho ngày hiện tại
        output = model_100(input_data_future, None, None, None)
        # Lưu dự báo của ngày hiện tại
        predicted_90.append(output[:, -1, :])  # Lấy dự báo cho ngày cuối cùng trong chuỗi thời gian
        # Cập nhật dữ liệu đầu vào cho ngày tiếp theo
        input_data_future = torch.cat([input_data_future[:, :, 1:], output], dim=2)
    # In ra dự báo cho tập test
    print("Predicted Output for data test:")
    for i in range(90):
        # In ra ngày tương ứng với dự báo
        print(f"Day  Predicted: {predicted_90[i][0]}")
# Out:
# Predicted Output for data test:
# Day  Predicted: tensor([593.3104])
# Day  Predicted: tensor([593.3046])
# Day  Predicted: tensor([593.2980])
# Day  Predicted: tensor([593.2914])
# Day  Predicted: tensor([593.2849])
# Day  Predicted: tensor([593.2783])
# Day  Predicted: tensor([593.2717])
# Day  Predicted: tensor([593.2651])
# Day  Predicted: tensor([593.2585])
# Day  Predicted: tensor([593.2519])
# Day  Predicted: tensor([593.2453])
# Day  Predicted: tensor([593.2387])
# Day  Predicted: tensor([593.2321])
# Day  Predicted: tensor([593.2255])
# Day  Predicted: tensor([593.2189])
# Day  Predicted: tensor([593.2123])
# Day  Predicted: tensor([593.2057])
# Day  Predicted: tensor([593.1992])
# Day  Predicted: tensor([593.1926])
# Day  Predicted: tensor([593.1860])
# Day  Predicted: tensor([593.1794])
# Day  Predicted: tensor([593.1729])
# Day  Predicted: tensor([593.1662])
# Day  Predicted: tensor([593.1596])
# Day  Predicted: tensor([593.1531])
# Day  Predicted: tensor([593.1464])
# Day  Predicted: tensor([593.1398])
# Day  Predicted: tensor([593.1333])
# Day  Predicted: tensor([593.1267])
# Day  Predicted: tensor([593.1201])
# Day  Predicted: tensor([593.1135])
# Day  Predicted: tensor([593.1069])
# Day  Predicted: tensor([593.1003])
# Day  Predicted: tensor([593.0938])
# Day  Predicted: tensor([593.0872])
# Day  Predicted: tensor([593.0806])
# Day  Predicted: tensor([593.0740])
# Day  Predicted: tensor([593.0674])
# Day  Predicted: tensor([593.0609])
# Day  Predicted: tensor([593.0542])
# Day  Predicted: tensor([593.0476])
# Day  Predicted: tensor([593.0410])
# Day  Predicted: tensor([593.0344])
# Day  Predicted: tensor([593.0279])
# Day  Predicted: tensor([593.0213])
# Day  Predicted: tensor([593.0147])
# Day  Predicted: tensor([593.0081])
# Day  Predicted: tensor([593.0015])
# Day  Predicted: tensor([592.9950])
# Day  Predicted: tensor([592.9883])
# Day  Predicted: tensor([592.9818])
# Day  Predicted: tensor([592.9752])
# Day  Predicted: tensor([592.9686])
# Day  Predicted: tensor([592.9620])
# Day  Predicted: tensor([592.9554])
# Day  Predicted: tensor([592.9488])
# Day  Predicted: tensor([592.9422])
# Day  Predicted: tensor([592.9356])
# Day  Predicted: tensor([592.9290])
# Day  Predicted: tensor([592.9224])
# Day  Predicted: tensor([592.9159])
# Day  Predicted: tensor([592.9092])
# Day  Predicted: tensor([592.9026])
# Day  Predicted: tensor([592.8961])
# Day  Predicted: tensor([592.8895])
# Day  Predicted: tensor([592.8829])
# Day  Predicted: tensor([592.8763])
# Day  Predicted: tensor([592.8697])
# Day  Predicted: tensor([592.8631])
# Day  Predicted: tensor([592.8566])
# Day  Predicted: tensor([592.8500])
# Day  Predicted: tensor([592.8434])
# Day  Predicted: tensor([592.8368])
# Day  Predicted: tensor([592.8302])
# Day  Predicted: tensor([592.8235])
# Day  Predicted: tensor([592.8170])
# Day  Predicted: tensor([592.8104])
# Day  Predicted: tensor([592.8039])
# Day  Predicted: tensor([592.7972])
# Day  Predicted: tensor([592.7906])
# Day  Predicted: tensor([592.7841])
# Day  Predicted: tensor([592.7775])
# Day  Predicted: tensor([592.7709])
# Day  Predicted: tensor([592.7643])
# Day  Predicted: tensor([592.7577])
# Day  Predicted: tensor([592.7512])
# Day  Predicted: tensor([592.7446])
# Day  Predicted: tensor([592.7379])
# Day  Predicted: tensor([592.7313])
# Day  Predicted: tensor([592.7247])

# %%
# Chuyển dữ liệu dự báo trên tập test từ tensor về numpy array
predicted_values_test = [pred[0].numpy() for pred in predicted_test]
# Chuyển dữ liệu dự báo 30/60/90 từ tensor về numpy array
predicted_values = [pred[0].numpy() for pred in predicted_90]
# Tạo index cho predicted_values
last_index = test_data.index.max()
index_future_30 = range(last_index + 1, last_index + 1+ 30)
index_future_60 = range(last_index + 31, last_index + 1+ 60)
index_future_90 = range(last_index + 61, last_index + 1+ 90)
# Chia predicted_values
split_size = len(predicted_values) // 3
predicted_values_30day = predicted_values[:split_size]
predicted_values_60day = predicted_values[split_size:2*split_size]
predicted_values_90day = predicted_values[2*split_size:]

# %%
# Vẽ biểu đồ
plt.figure(figsize=(12, 6))
plt.plot(train_data.index, train_data, label='Training Data')
plt.plot(test_data.index, test_data, label='Actual Data')
plt.plot(test_data.index, predicted_values_test, label='Predicted')
plt.plot(index_future_30,predicted_values_30day, label='Predicted 30 days')
plt.plot(index_future_60,predicted_values_60day, label='Predicted 60 days')
plt.plot(index_future_90,predicted_values_90day, label='Predicted 90 days')
plt.title('DLinear - 7:3')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
# Vẽ biểu đồ
plt.figure(figsize=(12, 6))
plt.plot(index_future_30,predicted_values_30day, label='Predicted 30 days', color='Red')
plt.plot(index_future_60,predicted_values_60day, label='Predicted 60 days', color='Purple')
plt.plot(index_future_90,predicted_values_90day, label='Predicted 90 days', color='Brown')
plt.title('DLinear - Predict 30/60/90 - 7:3')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
outputs_test = np.array(predicted_values_test)
outputs_test = outputs_test.flatten()
# Tính MAE
mae_test = np.mean(np.abs(test_data - outputs_test))
# Tính MAPE
mape_test = np.mean(np.abs((test_data - outputs_test) / test_data)) * 100
# Tính RMSE
rmse_test = np.sqrt(np.mean((test_data - outputs_test) ** 2))

print("MAE:", mae_test)
print("MAPE:", mape_test)
print("RMSE:", rmse_test)
# Out:
# MAE: 85.1880231698354
# MAPE: 20.981010219576113
# RMSE: 142.24611414538424
