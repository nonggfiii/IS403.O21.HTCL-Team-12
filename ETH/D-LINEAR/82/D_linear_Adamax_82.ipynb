# %% [markdown]
# #Run

# %%
# Thư viện
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from datetime import datetime, timedelta
import matplotlib.pyplot as plt

# %%
#  Model
class moving_avg(nn.Module):
    """
    Moving average block to highlight the trend of time series
    """

    def __init__(self, kernel_size, stride):
        super(moving_avg, self).__init__()
        self.kernel_size = kernel_size
        self.avg = nn.AvgPool1d(kernel_size=kernel_size, stride=stride, padding=0)

    def forward(self, x):
        # padding on the both ends of time series
        front = x[:, 0:1, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        end = x[:, -1:, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        x = torch.cat([front, x, end], dim=1)
        x = self.avg(x.permute(0, 2, 1))
        x = x.permute(0, 2, 1)
        return x
class series_decomp(nn.Module):
    """
    Series decomposition block
    """

    def __init__(self, kernel_size):
        super(series_decomp, self).__init__()
        self.moving_avg = moving_avg(kernel_size, stride=1)

    def forward(self, x):
        moving_mean = self.moving_avg(x)
        res = x - moving_mean
        return res, moving_mean

class Model(nn.Module):
    """
    Paper link: https://arxiv.org/pdf/2205.13504.pdf
    """

    def __init__(self, configs, individual=False):
        """
        individual: Bool, whether shared model among different variates.
        """
        super(Model, self).__init__()
        self.task_name = configs.task_name
        self.seq_len = configs.seq_len
        if self.task_name == 'classification' or self.task_name == 'anomaly_detection' or self.task_name == 'imputation':
            self.pred_len = configs.seq_len
        else:
            self.pred_len = configs.pred_len
        # Series decomposition block from Autoformer
        self.decompsition = series_decomp(configs.moving_avg)
        self.individual = individual
        self.channels = configs.enc_in

        if self.individual:
            self.Linear_Seasonal = nn.ModuleList()
            self.Linear_Trend = nn.ModuleList()

            for i in range(self.channels):
                self.Linear_Seasonal.append(
                    nn.Linear(self.seq_len, self.pred_len))
                self.Linear_Trend.append(
                    nn.Linear(self.seq_len, self.pred_len))

                self.Linear_Seasonal[i].weight = nn.Parameter(
                    (1 / self.seq_len) * torch.ones([self.pred_len, self.seq_len]))
                self.Linear_Trend[i].weight = nn.Parameter(
                    (1 / self.seq_len) * torch.ones([self.pred_len, self.seq_len]))
        else:
            self.Linear_Seasonal = nn.Linear(self.seq_len, self.pred_len)
            self.Linear_Trend = nn.Linear(self.seq_len, self.pred_len)

            self.Linear_Seasonal.weight = nn.Parameter(
                (1 / self.seq_len) * torch.ones([self.pred_len, self.seq_len]))
            self.Linear_Trend.weight = nn.Parameter(
                (1 / self.seq_len) * torch.ones([self.pred_len, self.seq_len]))

        if self.task_name == 'classification':
            self.act = F.gelu
            self.dropout = nn.Dropout(configs.dropout)
            self.projection = nn.Linear(
                configs.enc_in * configs.seq_len, configs.num_class)

    def encoder(self, x):
        seasonal_init, trend_init = self.decompsition(x)
        seasonal_init, trend_init = seasonal_init.permute(
            0, 2, 1), trend_init.permute(0, 2, 1)
        if self.individual:
            seasonal_output = torch.zeros([seasonal_init.size(0), seasonal_init.size(1), self.pred_len],
                                          dtype=seasonal_init.dtype).to(seasonal_init.device)
            trend_output = torch.zeros([trend_init.size(0), trend_init.size(1), self.pred_len],
                                       dtype=trend_init.dtype).to(trend_init.device)
            for i in range(self.channels):
                seasonal_output[:, i, :] = self.Linear_Seasonal[i](
                    seasonal_init[:, i, :])
                trend_output[:, i, :] = self.Linear_Trend[i](
                    trend_init[:, i, :])
        else:
            seasonal_output = self.Linear_Seasonal(seasonal_init)
            trend_output = self.Linear_Trend(trend_init)
        x = seasonal_output + trend_output
        return x.permute(0, 2, 1)

    def forecast(self, x_enc):
        # Encoder
        return self.encoder(x_enc)

    def imputation(self, x_enc):
        # Encoder
        return self.encoder(x_enc)

    def anomaly_detection(self, x_enc):
        # Encoder
        return self.encoder(x_enc)

    def classification(self, x_enc):
        # Encoder
        enc_out = self.encoder(x_enc)
        # Output
        # (batch_size, seq_length * d_model)
        output = enc_out.reshape(enc_out.shape[0], -1)
        # (batch_size, num_classes)
        output = self.projection(output)
        return output

    def forward(self, x_enc, x_mark_enc, x_dec, x_mark_dec, mask=None):
        if self.task_name == 'long_term_forecast' or self.task_name == 'short_term_forecast':
            dec_out = self.forecast(x_enc)
            return dec_out[:, -self.pred_len:, :]  # [B, L, D]
        if self.task_name == 'imputation':
            dec_out = self.imputation(x_enc)
            return dec_out  # [B, L, D]
        if self.task_name == 'anomaly_detection':
            dec_out = self.anomaly_detection(x_enc)
            return dec_out  # [B, L, D]
        if self.task_name == 'classification':
            dec_out = self.classification(x_enc)
            return dec_out  # [B, N]
        return None

# %%
# Đọc dữ liệu từ file đã xử lý
df = pd.read_excel('/content/eth_processed_data.xlsx')

# %%
# Chọn các cột dữ liệu số
numeric_columns = ['Close']
# Chuyển các giá trị số thành tensor
numeric_data = df[numeric_columns].values.astype(np.float32)
# Mở rộng chiều để phù hợp với đầu vào của mô hình
numeric_data = np.expand_dims(numeric_data, axis=0)

# Lấy dữ liệu cần phân tích
time_series_Close = df['Close']
# Lấy kích thước tập train (8:2)
train_size= int(0.8 * len(time_series_Close))
# Phân chia dữ liệu thành tập huấn luyện và tập kiểm tra (8:2)
train_data = time_series_Close[:train_size]
test_data = time_series_Close[train_size:]
# Chia dữ liệu thành tensor
input_data_train = torch.tensor(numeric_data[:, :len(train_data), :])
input_data_test = torch.tensor(numeric_data[:, len(train_data):, :])
# Lấy dữ liệu 100 ngày gần nhất
recent_100_Close = time_series_Close[-100:]

# Chuyển đổi dữ liệu 100 ngày gần nhất thành numpy array và mở rộng chiều
recent_100_Close_array = recent_100_Close.values.astype(np.float32)
recent_100_Close_array = np.expand_dims(recent_100_Close_array, axis=0)
recent_100_Close_array = np.expand_dims(recent_100_Close_array, axis=-1)
# Chuyển đổi thành tensor
input_data_100day = torch.tensor(recent_100_Close_array)

# In ra để kiểm tra kích thước của các tensor
print("Kích thước tập huấn luyện:", input_data_train.shape)
print("Kích thước tập kiểm tra:", input_data_test.shape)
# Out:
# Kích thước tập huấn luyện: torch.Size([1, 1535, 1])
# Kích thước tập kiểm tra: torch.Size([1, 384, 1])

# %%
class Configs:
    def __init__(self, moving_avg):
        self.task_name = 'long_term_forecast'  # Loại nhiệm vụ: dự đoán cho tương lai
        self.seq_len = 1535  # Độ dài của chuỗi đầu vào
        self.pred_len = 1535  # Độ dài của chuỗi đầu ra dự đoán
        self.enc_in = 64  # Số kênh đầu vào cho bộ mã hóa
        self.num_class = 5  # Số lớp cho bài toán phân loại
        self.dropout = 0.1  # Tỷ lệ dropout
        self.moving_avg = moving_avg

configs = Configs(moving_avg=25)

# Khởi tạo model
model = Model(configs)
model
# Out:
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): moving_avg(
#       (avg): AvgPool1d(kernel_size=(25,), stride=(1,), padding=(0,))
#     )
#   )
#   (Linear_Seasonal): Linear(in_features=1535, out_features=1535, bias=True)
#   (Linear_Trend): Linear(in_features=1535, out_features=1535, bias=True)
# )

# %%
# Xác định hàm mất mát và trình tối ưu hóa
criterion = nn.MSELoss()
optimizer = optim.Adamax(model.parameters(), lr=0.001)  # Có thể điều chỉnh lr theo yêu cầu

# Huấn luyện mô hình
num_epochs = 100  # Số lượng epoch
for epoch in range(num_epochs):
    model.train()  # Chuyển sang chế độ huấn luyện
    optimizer.zero_grad()  # Đặt gradient về 0
    # Feedforward
    outputs = model(input_data_train, None, None, None)
    # Tính toán loss
    loss = criterion(outputs, input_data_train)  # So sánh đầu ra với đầu vào
    # Backpropagation
    loss.backward()  # Tính toán gradient
    optimizer.step()  # Cập nhật trọng số
    # In ra loss sau mỗi epoch
    print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item():.4f}')
# Out:
# Epoch [1/100], Loss: 1515987.1250
# Epoch [2/100], Loss: 1929938.5000
# Epoch [3/100], Loss: 1021211.2500
# Epoch [4/100], Loss: 293292.3438
# Epoch [5/100], Loss: 474200.6875
# Epoch [6/100], Loss: 783775.1250
# Epoch [7/100], Loss: 707374.1875
# Epoch [8/100], Loss: 380967.7812
# Epoch [9/100], Loss: 131784.2969
# Epoch [10/100], Loss: 96543.7422
# Epoch [11/100], Loss: 192336.1406
# Epoch [12/100], Loss: 276660.7188
# Epoch [13/100], Loss: 278589.5938
# Epoch [14/100], Loss: 217255.5938
# Epoch [15/100], Loss: 147271.3594
# Epoch [16/100], Loss: 104198.1797
# Epoch [17/100], Loss: 89073.4062
# Epoch [18/100], Loss: 85210.8750
# Epoch [19/100], Loss: 80101.7969
# Epoch [20/100], Loss: 73328.4609
# Epoch [21/100], Loss: 70164.9219
# Epoch [22/100], Loss: 72083.4609
# Epoch [23/100], Loss: 73929.2500
# Epoch [24/100], Loss: 68786.8125
# Epoch [25/100], Loss: 54614.4141
# Epoch [26/100], Loss: 36412.7852
# Epoch [27/100], Loss: 22491.2461
# Epoch [28/100], Loss: 18369.6113
# Epoch [29/100], Loss: 23181.9824
# Epoch [30/100], Loss: 30887.8594
# Epoch [31/100], Loss: 34793.0938
# Epoch [32/100], Loss: 31812.9922
# Epoch [33/100], Loss: 23698.7578
# Epoch [34/100], Loss: 14989.0049
# Epoch [35/100], Loss: 9651.3662
# Epoch [36/100], Loss: 8825.5215
# Epoch [37/100], Loss: 10841.2109
# Epoch [38/100], Loss: 12954.6426
# Epoch [39/100], Loss: 13279.8984
# Epoch [40/100], Loss: 11649.5801
# Epoch [41/100], Loss: 9157.5850
# Epoch [42/100], Loss: 7056.0044
# Epoch [43/100], Loss: 5911.9233
# Epoch [44/100], Loss: 5497.8506
# Epoch [45/100], Loss: 5256.8696
# Epoch [46/100], Loss: 4835.0127
# Epoch [47/100], Loss: 4275.1499
# Epoch [48/100], Loss: 3829.5867
# Epoch [49/100], Loss: 3646.3164
# Epoch [50/100], Loss: 3616.8147
# Epoch [51/100], Loss: 3480.5674
# Epoch [52/100], Loss: 3057.8438
# Epoch [53/100], Loss: 2401.9424
# Epoch [54/100], Loss: 1757.0847
# Epoch [55/100], Loss: 1373.7627
# Epoch [56/100], Loss: 1333.9128
# Epoch [57/100], Loss: 1510.5679
# Epoch [58/100], Loss: 1673.0142
# Epoch [59/100], Loss: 1645.2092
# Epoch [60/100], Loss: 1403.6692
# Epoch [61/100], Loss: 1061.5162
# Epoch [62/100], Loss: 770.8173
# Epoch [63/100], Loss: 622.4475
# Epoch [64/100], Loss: 607.3104
# Epoch [65/100], Loss: 648.5939
# Epoch [66/100], Loss: 666.6050
# Epoch [67/100], Loss: 626.4837
# Epoch [68/100], Loss: 543.4295
# Epoch [69/100], Loss: 454.8415
# Epoch [70/100], Loss: 387.8761
# Epoch [71/100], Loss: 345.5357
# Epoch [72/100], Loss: 314.6971
# Epoch [73/100], Loss: 283.0391
# Epoch [74/100], Loss: 249.3158
# Epoch [75/100], Loss: 220.9205
# Epoch [76/100], Loss: 204.1486
# Epoch [77/100], Loss: 197.0261
# Epoch [78/100], Loss: 190.4028
# Epoch [79/100], Loss: 175.2948
# Epoch [80/100], Loss: 149.8155
# Epoch [81/100], Loss: 120.3092
# Epoch [82/100], Loss: 96.4328
# Epoch [83/100], Loss: 84.3935
# Epoch [84/100], Loss: 83.2666
# Epoch [85/100], Loss: 86.4276
# Epoch [86/100], Loss: 86.3656
# Epoch [87/100], Loss: 79.2317
# Epoch [88/100], Loss: 66.3358
# Epoch [89/100], Loss: 52.2944
# Epoch [90/100], Loss: 41.6681
# Epoch [91/100], Loss: 36.4183
# Epoch [92/100], Loss: 35.4607
# Epoch [93/100], Loss: 36.0252
# Epoch [94/100], Loss: 35.5624
# Epoch [95/100], Loss: 32.9778
# Epoch [96/100], Loss: 28.7186
# Epoch [97/100], Loss: 24.0300
# Epoch [98/100], Loss: 20.0536
# Epoch [99/100], Loss: 17.3015
# Epoch [100/100], Loss: 15.6448

# %%
# Dự báo cho tập test
# # Chuyển sang chế độ đánh giá
model.eval()
# Không cần tính gradient trong quá trình dự báo
with torch.no_grad():
    input_data_train = input_data_train.clone()  # Tạo một bản sao của dữ liệu đầu vào để cập nhật dự báo
    predicted_test = []  # Danh sách dự báo cho các ngày tiếp theo
    for i in range(len(test_data)):  # Dự báo cho tập test
        # Dự báo cho ngày hiện tại
        output = model(input_data_train, None, None, None)
        # Lưu dự báo của ngày hiện tại
        predicted_test.append(output[:, -1, :])  # Lấy dự báo cho ngày cuối cùng trong chuỗi thời gian
        # Cập nhật dữ liệu đầu vào cho ngày tiếp theo
        input_data_train = torch.cat([input_data_train[:, :, 1:], output], dim=2)
    # In ra dự báo cho tập test
    print("Predicted Output for data test:")
    for i in range(len(test_data)):
        # In ra ngày tương ứng với dự báo
        print(f"Day  Predicted: {predicted_test[i][0]}")
# Out:
# Predicted Output for data test:
# Day  Predicted: tensor([1798.3495])
# Day  Predicted: tensor([1799.7300])
# Day  Predicted: tensor([1801.1157])
# Day  Predicted: tensor([1802.5028])
# Day  Predicted: tensor([1803.8907])
# Day  Predicted: tensor([1805.2798])
# Day  Predicted: tensor([1806.6702])
# Day  Predicted: tensor([1808.0614])
# Day  Predicted: tensor([1809.4539])
# Day  Predicted: tensor([1810.8473])
# Day  Predicted: tensor([1812.2417])
# Day  Predicted: tensor([1813.6373])
# Day  Predicted: tensor([1815.0339])
# Day  Predicted: tensor([1816.4316])
# Day  Predicted: tensor([1817.8304])
# Day  Predicted: tensor([1819.2302])
# Day  Predicted: tensor([1820.6312])
# Day  Predicted: tensor([1822.0332])
# Day  Predicted: tensor([1823.4362])
# Day  Predicted: tensor([1824.8406])
# Day  Predicted: tensor([1826.2458])
# Day  Predicted: tensor([1827.6523])
# Day  Predicted: tensor([1829.0596])
# Day  Predicted: tensor([1830.4683])
# Day  Predicted: tensor([1831.8777])
# Day  Predicted: tensor([1833.2885])
# Day  Predicted: tensor([1834.7001])
# Day  Predicted: tensor([1836.1129])
# Day  Predicted: tensor([1837.5270])
# Day  Predicted: tensor([1838.9420])
# Day  Predicted: tensor([1840.3583])
# Day  Predicted: tensor([1841.7754])
# Day  Predicted: tensor([1843.1937])
# Day  Predicted: tensor([1844.6132])
# Day  Predicted: tensor([1846.0337])
# Day  Predicted: tensor([1847.4552])
# Day  Predicted: tensor([1848.8781])
# Day  Predicted: tensor([1850.3016])
# Day  Predicted: tensor([1851.7266])
# Day  Predicted: tensor([1853.1526])
# Day  Predicted: tensor([1854.5797])
# Day  Predicted: tensor([1856.0079])
# Day  Predicted: tensor([1857.4373])
# Day  Predicted: tensor([1858.8677])
# Day  Predicted: tensor([1860.2991])
# Day  Predicted: tensor([1861.7317])
# Day  Predicted: tensor([1863.1653])
# Day  Predicted: tensor([1864.6001])
# Day  Predicted: tensor([1866.0360])
# Day  Predicted: tensor([1867.4730])
# Day  Predicted: tensor([1868.9111])
# Day  Predicted: tensor([1870.3503])
# Day  Predicted: tensor([1871.7908])
# Day  Predicted: tensor([1873.2323])
# Day  Predicted: tensor([1874.6746])
# Day  Predicted: tensor([1876.1185])
# Day  Predicted: tensor([1877.5632])
# Day  Predicted: tensor([1879.0092])
# Day  Predicted: tensor([1880.4561])
# Day  Predicted: tensor([1881.9043])
# Day  Predicted: tensor([1883.3535])
# Day  Predicted: tensor([1884.8037])
# Day  Predicted: tensor([1886.2552])
# Day  Predicted: tensor([1887.7079])
# Day  Predicted: tensor([1889.1614])
# Day  Predicted: tensor([1890.6165])
# Day  Predicted: tensor([1892.0724])
# Day  Predicted: tensor([1893.5294])
# Day  Predicted: tensor([1894.9875])
# Day  Predicted: tensor([1896.4468])
# Day  Predicted: tensor([1897.9072])
# Day  Predicted: tensor([1899.3688])
# Day  Predicted: tensor([1900.8315])
# Day  Predicted: tensor([1902.2954])
# Day  Predicted: tensor([1903.7604])
# Day  Predicted: tensor([1905.2264])
# Day  Predicted: tensor([1906.6936])
# Day  Predicted: tensor([1908.1620])
# Day  Predicted: tensor([1909.6313])
# Day  Predicted: tensor([1911.1021])
# Day  Predicted: tensor([1912.5737])
# Day  Predicted: tensor([1914.0465])
# Day  Predicted: tensor([1915.5205])
# Day  Predicted: tensor([1916.9957])
# Day  Predicted: tensor([1918.4718])
# Day  Predicted: tensor([1919.9492])
# Day  Predicted: tensor([1921.4279])
# Day  Predicted: tensor([1922.9073])
# Day  Predicted: tensor([1924.3883])
# Day  Predicted: tensor([1925.8704])
# Day  Predicted: tensor([1927.3534])
# Day  Predicted: tensor([1928.8375])
# Day  Predicted: tensor([1930.3230])
# Day  Predicted: tensor([1931.8094])
# Day  Predicted: tensor([1933.2974])
# Day  Predicted: tensor([1934.7861])
# Day  Predicted: tensor([1936.2761])
# Day  Predicted: tensor([1937.7672])
# Day  Predicted: tensor([1939.2595])
# Day  Predicted: tensor([1940.7528])
# Day  Predicted: tensor([1942.2473])
# Day  Predicted: tensor([1943.7429])
# Day  Predicted: tensor([1945.2400])
# Day  Predicted: tensor([1946.7378])
# Day  Predicted: tensor([1948.2372])
# Day  Predicted: tensor([1949.7374])
# Day  Predicted: tensor([1951.2388])
# Day  Predicted: tensor([1952.7417])
# Day  Predicted: tensor([1954.2455])
# Day  Predicted: tensor([1955.7504])
# Day  Predicted: tensor([1957.2563])
# Day  Predicted: tensor([1958.7639])
# Day  Predicted: tensor([1960.2722])
# Day  Predicted: tensor([1961.7820])
# Day  Predicted: tensor([1963.2926])
# Day  Predicted: tensor([1964.8044])
# Day  Predicted: tensor([1966.3177])
# Day  Predicted: tensor([1967.8318])
# Day  Predicted: tensor([1969.3473])
# Day  Predicted: tensor([1970.8639])
# Day  Predicted: tensor([1972.3816])
# Day  Predicted: tensor([1973.9006])
# Day  Predicted: tensor([1975.4209])
# Day  Predicted: tensor([1976.9419])
# Day  Predicted: tensor([1978.4642])
# Day  Predicted: tensor([1979.9879])
# Day  Predicted: tensor([1981.5129])
# Day  Predicted: tensor([1983.0388])
# Day  Predicted: tensor([1984.5659])
# Day  Predicted: tensor([1986.0941])
# Day  Predicted: tensor([1987.6238])
# Day  Predicted: tensor([1989.1545])
# Day  Predicted: tensor([1990.6863])
# Day  Predicted: tensor([1992.2192])
# Day  Predicted: tensor([1993.7534])
# Day  Predicted: tensor([1995.2887])
# Day  Predicted: tensor([1996.8253])
# Day  Predicted: tensor([1998.3634])
# Day  Predicted: tensor([1999.9022])
# Day  Predicted: tensor([2001.4424])
# Day  Predicted: tensor([2002.9835])
# Day  Predicted: tensor([2004.5261])
# Day  Predicted: tensor([2006.0698])
# Day  Predicted: tensor([2007.6147])
# Day  Predicted: tensor([2009.1609])
# Day  Predicted: tensor([2010.7080])
# Day  Predicted: tensor([2012.2563])
# Day  Predicted: tensor([2013.8063])
# Day  Predicted: tensor([2015.3569])
# Day  Predicted: tensor([2016.9091])
# Day  Predicted: tensor([2018.4622])
# Day  Predicted: tensor([2020.0166])
# Day  Predicted: tensor([2021.5723])
# Day  Predicted: tensor([2023.1292])
# Day  Predicted: tensor([2024.6871])
# Day  Predicted: tensor([2026.2463])
# Day  Predicted: tensor([2027.8068])
# Day  Predicted: tensor([2029.3684])
# Day  Predicted: tensor([2030.9312])
# Day  Predicted: tensor([2032.4952])
# Day  Predicted: tensor([2034.0604])
# Day  Predicted: tensor([2035.6268])
# Day  Predicted: tensor([2037.1946])
# Day  Predicted: tensor([2038.7635])
# Day  Predicted: tensor([2040.3334])
# Day  Predicted: tensor([2041.9048])
# Day  Predicted: tensor([2043.4773])
# Day  Predicted: tensor([2045.0510])
# Day  Predicted: tensor([2046.6257])
# Day  Predicted: tensor([2048.2019])
# Day  Predicted: tensor([2049.7795])
# Day  Predicted: tensor([2051.3582])
# Day  Predicted: tensor([2052.9375])
# Day  Predicted: tensor([2054.5186])
# Day  Predicted: tensor([2056.1008])
# Day  Predicted: tensor([2057.6841])
# Day  Predicted: tensor([2059.2690])
# Day  Predicted: tensor([2060.8547])
# Day  Predicted: tensor([2062.4419])
# Day  Predicted: tensor([2064.0300])
# Day  Predicted: tensor([2065.6196])
# Day  Predicted: tensor([2067.2104])
# Day  Predicted: tensor([2068.8025])
# Day  Predicted: tensor([2070.3955])
# Day  Predicted: tensor([2071.9902])
# Day  Predicted: tensor([2073.5857])
# Day  Predicted: tensor([2075.1826])
# Day  Predicted: tensor([2076.7808])
# Day  Predicted: tensor([2078.3801])
# Day  Predicted: tensor([2079.9807])
# Day  Predicted: tensor([2081.5825])
# Day  Predicted: tensor([2083.1858])
# Day  Predicted: tensor([2084.7900])
# Day  Predicted: tensor([2086.3953])
# Day  Predicted: tensor([2088.0022])
# Day  Predicted: tensor([2089.6104])
# Day  Predicted: tensor([2091.2195])
# Day  Predicted: tensor([2092.8298])
# Day  Predicted: tensor([2094.4417])
# Day  Predicted: tensor([2096.0547])
# Day  Predicted: tensor([2097.6687])
# Day  Predicted: tensor([2099.2842])
# Day  Predicted: tensor([2100.9009])
# Day  Predicted: tensor([2102.5190])
# Day  Predicted: tensor([2104.1382])
# Day  Predicted: tensor([2105.7583])
# Day  Predicted: tensor([2107.3806])
# Day  Predicted: tensor([2109.0029])
# Day  Predicted: tensor([2110.6272])
# Day  Predicted: tensor([2112.2527])
# Day  Predicted: tensor([2113.8796])
# Day  Predicted: tensor([2115.5076])
# Day  Predicted: tensor([2117.1365])
# Day  Predicted: tensor([2118.7668])
# Day  Predicted: tensor([2120.3984])
# Day  Predicted: tensor([2122.0315])
# Day  Predicted: tensor([2123.6658])
# Day  Predicted: tensor([2125.3010])
# Day  Predicted: tensor([2126.9382])
# Day  Predicted: tensor([2128.5759])
# Day  Predicted: tensor([2130.2151])
# Day  Predicted: tensor([2131.8555])
# Day  Predicted: tensor([2133.4976])
# Day  Predicted: tensor([2135.1406])
# Day  Predicted: tensor([2136.7849])
# Day  Predicted: tensor([2138.4304])
# Day  Predicted: tensor([2140.0774])
# Day  Predicted: tensor([2141.7251])
# Day  Predicted: tensor([2143.3748])
# Day  Predicted: tensor([2145.0254])
# Day  Predicted: tensor([2146.6775])
# Day  Predicted: tensor([2148.3306])
# Day  Predicted: tensor([2149.9849])
# Day  Predicted: tensor([2151.6404])
# Day  Predicted: tensor([2153.2979])
# Day  Predicted: tensor([2154.9561])
# Day  Predicted: tensor([2156.6155])
# Day  Predicted: tensor([2158.2766])
# Day  Predicted: tensor([2159.9387])
# Day  Predicted: tensor([2161.6018])
# Day  Predicted: tensor([2163.2666])
# Day  Predicted: tensor([2164.9324])
# Day  Predicted: tensor([2166.5999])
# Day  Predicted: tensor([2168.2681])
# Day  Predicted: tensor([2169.9382])
# Day  Predicted: tensor([2171.6096])
# Day  Predicted: tensor([2173.2820])
# Day  Predicted: tensor([2174.9553])
# Day  Predicted: tensor([2176.6306])
# Day  Predicted: tensor([2178.3066])
# Day  Predicted: tensor([2179.9846])
# Day  Predicted: tensor([2181.6633])
# Day  Predicted: tensor([2183.3430])
# Day  Predicted: tensor([2185.0249])
# Day  Predicted: tensor([2186.7073])
# Day  Predicted: tensor([2188.3916])
# Day  Predicted: tensor([2190.0767])
# Day  Predicted: tensor([2191.7632])
# Day  Predicted: tensor([2193.4514])
# Day  Predicted: tensor([2195.1404])
# Day  Predicted: tensor([2196.8311])
# Day  Predicted: tensor([2198.5229])
# Day  Predicted: tensor([2200.2161])
# Day  Predicted: tensor([2201.9106])
# Day  Predicted: tensor([2203.6062])
# Day  Predicted: tensor([2205.3037])
# Day  Predicted: tensor([2207.0020])
# Day  Predicted: tensor([2208.7012])
# Day  Predicted: tensor([2210.4026])
# Day  Predicted: tensor([2212.1045])
# Day  Predicted: tensor([2213.8083])
# Day  Predicted: tensor([2215.5132])
# Day  Predicted: tensor([2217.2195])
# Day  Predicted: tensor([2218.9270])
# Day  Predicted: tensor([2220.6357])
# Day  Predicted: tensor([2222.3459])
# Day  Predicted: tensor([2224.0574])
# Day  Predicted: tensor([2225.7705])
# Day  Predicted: tensor([2227.4844])
# Day  Predicted: tensor([2229.1997])
# Day  Predicted: tensor([2230.9165])
# Day  Predicted: tensor([2232.6345])
# Day  Predicted: tensor([2234.3542])
# Day  Predicted: tensor([2236.0747])
# Day  Predicted: tensor([2237.7969])
# Day  Predicted: tensor([2239.5203])
# Day  Predicted: tensor([2241.2449])
# Day  Predicted: tensor([2242.9712])
# Day  Predicted: tensor([2244.6987])
# Day  Predicted: tensor([2246.4272])
# Day  Predicted: tensor([2248.1567])
# Day  Predicted: tensor([2249.8884])
# Day  Predicted: tensor([2251.6211])
# Day  Predicted: tensor([2253.3555])
# Day  Predicted: tensor([2255.0903])
# Day  Predicted: tensor([2256.8274])
# Day  Predicted: tensor([2258.5654])
# Day  Predicted: tensor([2260.3049])
# Day  Predicted: tensor([2262.0457])
# Day  Predicted: tensor([2263.7876])
# Day  Predicted: tensor([2265.5308])
# Day  Predicted: tensor([2267.2756])
# Day  Predicted: tensor([2269.0217])
# Day  Predicted: tensor([2270.7693])
# Day  Predicted: tensor([2272.5181])
# Day  Predicted: tensor([2274.2683])
# Day  Predicted: tensor([2276.0195])
# Day  Predicted: tensor([2277.7727])
# Day  Predicted: tensor([2279.5266])
# Day  Predicted: tensor([2281.2825])
# Day  Predicted: tensor([2283.0391])
# Day  Predicted: tensor([2284.7974])
# Day  Predicted: tensor([2286.5571])
# Day  Predicted: tensor([2288.3179])
# Day  Predicted: tensor([2290.0798])
# Day  Predicted: tensor([2291.8440])
# Day  Predicted: tensor([2293.6089])
# Day  Predicted: tensor([2295.3752])
# Day  Predicted: tensor([2297.1431])
# Day  Predicted: tensor([2298.9119])
# Day  Predicted: tensor([2300.6826])
# Day  Predicted: tensor([2302.4546])
# Day  Predicted: tensor([2304.2278])
# Day  Predicted: tensor([2306.0024])
# Day  Predicted: tensor([2307.7783])
# Day  Predicted: tensor([2309.5552])
# Day  Predicted: tensor([2311.3340])
# Day  Predicted: tensor([2313.1143])
# Day  Predicted: tensor([2314.8958])
# Day  Predicted: tensor([2316.6782])
# Day  Predicted: tensor([2318.4626])
# Day  Predicted: tensor([2320.2480])
# Day  Predicted: tensor([2322.0347])
# Day  Predicted: tensor([2323.8235])
# Day  Predicted: tensor([2325.6128])
# Day  Predicted: tensor([2327.4038])
# Day  Predicted: tensor([2329.1965])
# Day  Predicted: tensor([2330.9900])
# Day  Predicted: tensor([2332.7852])
# Day  Predicted: tensor([2334.5820])
# Day  Predicted: tensor([2336.3799])
# Day  Predicted: tensor([2338.1792])
# Day  Predicted: tensor([2339.9797])
# Day  Predicted: tensor([2341.7820])
# Day  Predicted: tensor([2343.5857])
# Day  Predicted: tensor([2345.3901])
# Day  Predicted: tensor([2347.1968])
# Day  Predicted: tensor([2349.0042])
# Day  Predicted: tensor([2350.8132])
# Day  Predicted: tensor([2352.6240])
# Day  Predicted: tensor([2354.4358])
# Day  Predicted: tensor([2356.2485])
# Day  Predicted: tensor([2358.0635])
# Day  Predicted: tensor([2359.8794])
# Day  Predicted: tensor([2361.6970])
# Day  Predicted: tensor([2363.5156])
# Day  Predicted: tensor([2365.3362])
# Day  Predicted: tensor([2367.1577])
# Day  Predicted: tensor([2368.9807])
# Day  Predicted: tensor([2370.8052])
# Day  Predicted: tensor([2372.6311])
# Day  Predicted: tensor([2374.4585])
# Day  Predicted: tensor([2376.2871])
# Day  Predicted: tensor([2378.1169])
# Day  Predicted: tensor([2379.9485])
# Day  Predicted: tensor([2381.7812])
# Day  Predicted: tensor([2383.6155])
# Day  Predicted: tensor([2385.4514])
# Day  Predicted: tensor([2387.2886])
# Day  Predicted: tensor([2389.1272])
# Day  Predicted: tensor([2390.9673])
# Day  Predicted: tensor([2392.8083])
# Day  Predicted: tensor([2394.6511])
# Day  Predicted: tensor([2396.4954])
# Day  Predicted: tensor([2398.3408])
# Day  Predicted: tensor([2400.1882])
# Day  Predicted: tensor([2402.0364])
# Day  Predicted: tensor([2403.8865])
# Day  Predicted: tensor([2405.7375])
# Day  Predicted: tensor([2407.5906])
# Day  Predicted: tensor([2409.4446])
# Day  Predicted: tensor([2411.3003])
# Day  Predicted: tensor([2413.1575])
# Day  Predicted: tensor([2415.0159])

# %%
class Configs:
    def __init__(self, moving_avg):
        self.task_name = 'long_term_forecast'  # Loại nhiệm vụ: dự đoán cho tương lai
        self.seq_len = 100  # Độ dài của chuỗi đầu vào
        self.pred_len = 100  # Độ dài của chuỗi đầu ra dự đoán
        self.enc_in = 64  # Số kênh đầu vào cho bộ mã hóa
        self.num_class = 5  # Số lớp cho bài toán phân loại
        self.dropout = 0.1  # Tỷ lệ dropout
        self.moving_avg = moving_avg

configs = Configs(moving_avg=25)

# Khởi tạo model
model_100 = Model(configs)
model_100
# Out:
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): moving_avg(
#       (avg): AvgPool1d(kernel_size=(25,), stride=(1,), padding=(0,))
#     )
#   )
#   (Linear_Seasonal): Linear(in_features=100, out_features=100, bias=True)
#   (Linear_Trend): Linear(in_features=100, out_features=100, bias=True)
# )

# %%
# Xác định hàm mất mát và trình tối ưu hóa
criterion = nn.MSELoss()
optimizer = optim.Adamax(model_100.parameters(), lr=0.001)  # Có thể điều chỉnh lr theo yêu cầu
# Huấn luyện mô hình
num_epochs = 100  # Số lượng epoch
for epoch in range(num_epochs):
    model_100.train()  # Chuyển sang chế độ huấn luyện
    optimizer.zero_grad()  # Đặt gradient về 0
    # Feedforward
    outputs = model_100(input_data_100day, None, None, None)
    # Tính toán loss
    loss = criterion(outputs, input_data_100day)  # So sánh đầu ra với đầu vào
    # Backpropagation
    loss.backward()  # Tính toán gradient
    optimizer.step()  # Cập nhật trọng số
    # In ra loss sau mỗi epoch
    print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item():.4f}')
# Out:
# Epoch [1/100], Loss: 100691.2500
# Epoch [2/100], Loss: 29404.1094
# Epoch [3/100], Loss: 22701.3770
# Epoch [4/100], Loss: 22695.5742
# Epoch [5/100], Loss: 23961.7148
# Epoch [6/100], Loss: 22061.4023
# Epoch [7/100], Loss: 16273.5088
# Epoch [8/100], Loss: 9784.2793
# Epoch [9/100], Loss: 5854.6973
# Epoch [10/100], Loss: 5248.2632
# Epoch [11/100], Loss: 6504.6963
# Epoch [12/100], Loss: 7658.9707
# Epoch [13/100], Loss: 7621.2104
# Epoch [14/100], Loss: 6465.8638
# Epoch [15/100], Loss: 4909.3843
# Epoch [16/100], Loss: 3634.6309
# Epoch [17/100], Loss: 2924.1094
# Epoch [18/100], Loss: 2678.7039
# Epoch [19/100], Loss: 2639.0056
# Epoch [20/100], Loss: 2591.0276
# Epoch [21/100], Loss: 2447.3481
# Epoch [22/100], Loss: 2219.1086
# Epoch [23/100], Loss: 1951.6196
# Epoch [24/100], Loss: 1682.0144
# Epoch [25/100], Loss: 1432.2607
# Epoch [26/100], Loss: 1218.8348
# Epoch [27/100], Loss: 1057.2319
# Epoch [28/100], Loss: 955.1266
# Epoch [29/100], Loss: 903.1365
# Epoch [30/100], Loss: 874.6118
# Epoch [31/100], Loss: 837.2908
# Epoch [32/100], Loss: 769.5993
# Epoch [33/100], Loss: 670.8440
# Epoch [34/100], Loss: 559.3074
# Epoch [35/100], Loss: 460.3542
# Epoch [36/100], Loss: 392.3663
# Epoch [37/100], Loss: 358.4065
# Epoch [38/100], Loss: 347.0448
# Epoch [39/100], Loss: 340.2534
# Epoch [40/100], Loss: 323.1139
# Epoch [41/100], Loss: 290.2489
# Epoch [42/100], Loss: 246.5147
# Epoch [43/100], Loss: 202.7148
# Epoch [44/100], Loss: 169.2623
# Epoch [45/100], Loss: 151.0732
# Epoch [46/100], Loss: 145.8749
# Epoch [47/100], Loss: 146.2009
# Epoch [48/100], Loss: 143.6329
# Epoch [49/100], Loss: 132.9585
# Epoch [50/100], Loss: 114.2428
# Epoch [51/100], Loss: 92.0365
# Epoch [52/100], Loss: 72.4480
# Epoch [53/100], Loss: 59.8623
# Epoch [54/100], Loss: 55.0151
# Epoch [55/100], Loss: 55.2390
# Epoch [56/100], Loss: 56.4094
# Epoch [57/100], Loss: 55.2600
# Epoch [58/100], Loss: 50.7706
# Epoch [59/100], Loss: 44.0504
# Epoch [60/100], Loss: 37.1222
# Epoch [61/100], Loss: 31.5389
# Epoch [62/100], Loss: 27.6758
# Epoch [63/100], Loss: 24.9351
# Epoch [64/100], Loss: 22.4919
# Epoch [65/100], Loss: 19.9593
# Epoch [66/100], Loss: 17.5445
# Epoch [67/100], Loss: 15.7129
# Epoch [68/100], Loss: 14.7027
# Epoch [69/100], Loss: 14.2799
# Epoch [70/100], Loss: 13.8770
# Epoch [71/100], Loss: 12.9729
# Epoch [72/100], Loss: 11.4178
# Epoch [73/100], Loss: 9.4933
# Epoch [74/100], Loss: 7.6965
# Epoch [75/100], Loss: 6.4250
# Epoch [76/100], Loss: 5.7734
# Epoch [77/100], Loss: 5.5409
# Epoch [78/100], Loss: 5.4068
# Epoch [79/100], Loss: 5.1317
# Epoch [80/100], Loss: 4.6604
# Epoch [81/100], Loss: 4.0908
# Epoch [82/100], Loss: 3.5639
# Epoch [83/100], Loss: 3.1623
# Epoch [84/100], Loss: 2.8771
# Epoch [85/100], Loss: 2.6428
# Epoch [86/100], Loss: 2.3988
# Epoch [87/100], Loss: 2.1287
# Epoch [88/100], Loss: 1.8589
# Epoch [89/100], Loss: 1.6280
# Epoch [90/100], Loss: 1.4563
# Epoch [91/100], Loss: 1.3350
# Epoch [92/100], Loss: 1.2375
# Epoch [93/100], Loss: 1.1398
# Epoch [94/100], Loss: 1.0336
# Epoch [95/100], Loss: 0.9256
# Epoch [96/100], Loss: 0.8276
# Epoch [97/100], Loss: 0.7460
# Epoch [98/100], Loss: 0.6773
# Epoch [99/100], Loss: 0.6125
# Epoch [100/100], Loss: 0.5453

# %%
# Dự báo cho 30/60/90
# # Chuyển sang chế độ đánh giá
model_100.eval()

# Không cần tính gradient trong quá trình dự báo
with torch.no_grad():
    input_data_future = input_data_100day.clone()  # Tạo một bản sao của dữ liệu đầu vào để cập nhật dự báo
    predicted_90 = []  # Danh sách dự báo cho các ngày tiếp theo
    for i in range(90):  # Dự báo cho tập test
        # Dự báo cho ngày hiện tại
        output = model_100(input_data_future, None, None, None)
        # Lưu dự báo của ngày hiện tại
        predicted_90.append(output[:, -1, :])  # Lấy dự báo cho ngày cuối cùng trong chuỗi thời gian
        # Cập nhật dữ liệu đầu vào cho ngày tiếp theo
        input_data_future = torch.cat([input_data_future[:, :, 1:], output], dim=2)
    # In ra dự báo cho tập test
    print("Predicted Output for data test:")
    for i in range(90):
        # In ra ngày tương ứng với dự báo
        print(f"Day  Predicted: {predicted_90[i][0]}")
# Out:
# Predicted Output for data test:
# Day  Predicted: tensor([3761.0137])
# Day  Predicted: tensor([3761.0122])
# Day  Predicted: tensor([3761.0042])
# Day  Predicted: tensor([3760.9958])
# Day  Predicted: tensor([3760.9873])
# Day  Predicted: tensor([3760.9788])
# Day  Predicted: tensor([3760.9705])
# Day  Predicted: tensor([3760.9624])
# Day  Predicted: tensor([3760.9539])
# Day  Predicted: tensor([3760.9453])
# Day  Predicted: tensor([3760.9370])
# Day  Predicted: tensor([3760.9287])
# Day  Predicted: tensor([3760.9202])
# Day  Predicted: tensor([3760.9119])
# Day  Predicted: tensor([3760.9036])
# Day  Predicted: tensor([3760.8950])
# Day  Predicted: tensor([3760.8867])
# Day  Predicted: tensor([3760.8782])
# Day  Predicted: tensor([3760.8699])
# Day  Predicted: tensor([3760.8618])
# Day  Predicted: tensor([3760.8530])
# Day  Predicted: tensor([3760.8450])
# Day  Predicted: tensor([3760.8362])
# Day  Predicted: tensor([3760.8279])
# Day  Predicted: tensor([3760.8196])
# Day  Predicted: tensor([3760.8113])
# Day  Predicted: tensor([3760.8027])
# Day  Predicted: tensor([3760.7944])
# Day  Predicted: tensor([3760.7861])
# Day  Predicted: tensor([3760.7778])
# Day  Predicted: tensor([3760.7693])
# Day  Predicted: tensor([3760.7607])
# Day  Predicted: tensor([3760.7524])
# Day  Predicted: tensor([3760.7439])
# Day  Predicted: tensor([3760.7356])
# Day  Predicted: tensor([3760.7273])
# Day  Predicted: tensor([3760.7192])
# Day  Predicted: tensor([3760.7104])
# Day  Predicted: tensor([3760.7021])
# Day  Predicted: tensor([3760.6938])
# Day  Predicted: tensor([3760.6855])
# Day  Predicted: tensor([3760.6770])
# Day  Predicted: tensor([3760.6687])
# Day  Predicted: tensor([3760.6602])
# Day  Predicted: tensor([3760.6519])
# Day  Predicted: tensor([3760.6436])
# Day  Predicted: tensor([3760.6350])
# Day  Predicted: tensor([3760.6267])
# Day  Predicted: tensor([3760.6182])
# Day  Predicted: tensor([3760.6099])
# Day  Predicted: tensor([3760.6016])
# Day  Predicted: tensor([3760.5930])
# Day  Predicted: tensor([3760.5850])
# Day  Predicted: tensor([3760.5764])
# Day  Predicted: tensor([3760.5679])
# Day  Predicted: tensor([3760.5596])
# Day  Predicted: tensor([3760.5510])
# Day  Predicted: tensor([3760.5427])
# Day  Predicted: tensor([3760.5342])
# Day  Predicted: tensor([3760.5256])
# Day  Predicted: tensor([3760.5176])
# Day  Predicted: tensor([3760.5090])
# Day  Predicted: tensor([3760.5007])
# Day  Predicted: tensor([3760.4924])
# Day  Predicted: tensor([3760.4841])
# Day  Predicted: tensor([3760.4756])
# Day  Predicted: tensor([3760.4670])
# Day  Predicted: tensor([3760.4587])
# Day  Predicted: tensor([3760.4504])
# Day  Predicted: tensor([3760.4421])
# Day  Predicted: tensor([3760.4336])
# Day  Predicted: tensor([3760.4253])
# Day  Predicted: tensor([3760.4167])
# Day  Predicted: tensor([3760.4084])
# Day  Predicted: tensor([3760.4001])
# Day  Predicted: tensor([3760.3916])
# Day  Predicted: tensor([3760.3833])
# Day  Predicted: tensor([3760.3750])
# Day  Predicted: tensor([3760.3667])
# Day  Predicted: tensor([3760.3582])
# Day  Predicted: tensor([3760.3499])
# Day  Predicted: tensor([3760.3413])
# Day  Predicted: tensor([3760.3330])
# Day  Predicted: tensor([3760.3245])
# Day  Predicted: tensor([3760.3162])
# Day  Predicted: tensor([3760.3076])
# Day  Predicted: tensor([3760.2993])
# Day  Predicted: tensor([3760.2910])
# Day  Predicted: tensor([3760.2827])
# Day  Predicted: tensor([3760.2744])

# %%
# Chuyển dữ liệu dự báo trên tập test từ tensor về numpy array
predicted_values_test = [pred[0].numpy() for pred in predicted_test]
# Chuyển dữ liệu dự báo 30/60/90 từ tensor về numpy array
predicted_values = [pred[0].numpy() for pred in predicted_90]
# Tạo index cho predicted_values
last_index = test_data.index.max()
index_future_30 = range(last_index + 1, last_index + 1+ 30)
index_future_60 = range(last_index + 31, last_index + 1+ 60)
index_future_90 = range(last_index + 61, last_index + 1+ 90)
# Chia predicted_values
split_size = len(predicted_values) // 3
predicted_values_30day = predicted_values[:split_size]
predicted_values_60day = predicted_values[split_size:2*split_size]
predicted_values_90day = predicted_values[2*split_size:]

# %%
# Vẽ biểu đồ
plt.figure(figsize=(12, 6))
plt.plot(train_data.index, train_data, label='Training Data')
plt.plot(test_data.index, test_data, label='Actual Data')
plt.plot(test_data.index, predicted_values_test, label='Predicted')
plt.plot(index_future_30,predicted_values_30day, label='Predicted 30 days')
plt.plot(index_future_60,predicted_values_60day, label='Predicted 60 days')
plt.plot(index_future_90,predicted_values_90day, label='Predicted 90 days')
plt.title('DLinear - 8:2')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
# Vẽ biểu đồ
plt.figure(figsize=(12, 6))
plt.plot(index_future_30,predicted_values_30day, label='Predicted 30 days', color='Red')
plt.plot(index_future_60,predicted_values_60day, label='Predicted 60 days', color='Purple')
plt.plot(index_future_90,predicted_values_90day, label='Predicted 90 days', color='Brown')
plt.title('DLinear - Predict 30/60/90 - 8:2')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
outputs_test = np.array(predicted_values_test)
outputs_test = outputs_test.flatten()
# Tính MAE
mae_test = np.mean(np.abs(test_data - outputs_test))
# Tính MAPE
mape_test = np.mean(np.abs((test_data - outputs_test) / test_data)) * 100
# Tính RMSE
rmse_test = np.sqrt(np.mean((test_data - outputs_test) ** 2))

print("MAE:", mae_test)
print("MAPE:", mape_test)
print("RMSE:", rmse_test)
# Out:
# MAE: 409.1815404891968
# MAPE: 15.071736128198921
# RMSE: 599.546202969887
